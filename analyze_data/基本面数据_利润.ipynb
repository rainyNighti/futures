# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
import gc
import shutil
import calmap
from operator import itemgetter
# 需要改为你的root
root_path = '/high_perf_store3/data-lm/xiezixun/futures_predict'
data_path = os.path.join(root_path, 'data/赛题数据发布/赛道一/基本面数据/基本面数据_利润.csv')

# 设置完整显示所有行列
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
    
df = pd.read_csv(data_path, low_memory=False)
df.shape
# Out:
# (2416, 10)

# %%
df.columns
# Out:
# Index(['指标名称', '原油：常减压：独立炼厂：装置毛利：中国（周）', '原油：炼油工序：毛利：中国：主营炼厂（周）',
#        '原油：炼油工序：毛利：山东：独立炼厂（周）', '柴油：裂解：价差：中国：主营销售公司（日）',
#        '汽油：裂解：价差：中国：主营销售公司（日）', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9'],
#       dtype='object')

# %%
df.head()
# Out:
#          指标名称  原油：常减压：独立炼厂：装置毛利：中国（周）  原油：炼油工序：毛利：中国：主营炼厂（周）  \
# 0  2019/01/04                 485.974                 454.86
# 1  2019/01/05                     NaN                    NaN
# 2  2019/01/06                     NaN                    NaN
# 3  2019/01/07                     NaN                    NaN
# 4  2019/01/08                     NaN                    NaN
#
#    原油：炼油工序：毛利：山东：独立炼厂（周）  柴油：裂解：价差：中国：主营销售公司（日）  汽油：裂解：价差：中国：主营销售公司（日）  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN

# %% [markdown]
# ## NAN Search

# %%
nans_df = df.isna()
nans_groups={}
for col in df.columns:
    cur_group = nans_df[col].sum()
    try:
        nans_groups[cur_group].append(col)
    except:
        nans_groups[cur_group]=[col]
del nans_df; x=gc.collect()
nans_groups = sorted(nans_groups.items(), key=itemgetter(0), reverse=True)
for k,v in nans_groups:
    print(f'{v}: NAN count = {k}, share = {round(k / len(df) * 100, 2)}%')
# Out:
# ['Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9']: NAN count = 2416, share = 100.0%
# ['原油：炼油工序：毛利：山东：独立炼厂（周）']: NAN count = 2133, share = 88.29%
# ['原油：常减压：独立炼厂：装置毛利：中国（周）']: NAN count = 2072, share = 85.76%
# ['原油：炼油工序：毛利：中国：主营炼厂（周）']: NAN count = 2070, share = 85.68%
# ['柴油：裂解：价差：中国：主营销售公司（日）', '汽油：裂解：价差：中国：主营销售公司（日）']: NAN count = 1051, share = 43.5%
# ['指标名称']: NAN count = 0, share = 0.0%

# %% [markdown]
# # 离散值 & 连续值EDA

# %%
def summarize_df(df, nunique_threshold=100):
    """
    nunique_threshold : 一个数值型特征如果其唯一值数量低于此阈值，将被当作离散变量处理。
    """
    # 1. 连续变量分析
    # -------------------
    # 选择数值类型且唯一值数量 > nunique_threshold 的列
    continuous_cols = [
        col for col in df.columns 
        if pd.api.types.is_numeric_dtype(df[col]) and df[col].nunique() > nunique_threshold
    ]
    
    if continuous_cols:
        print("\n--- 1. 连续变量统计摘要 ---\n")
        
        # 使用describe高效计算基础统计量
        summary_conti = df[continuous_cols].describe().T
        
        # 添加更多有用的统计信息
        summary_conti['var'] = df[continuous_cols].var()
        summary_conti['skew'] = df[continuous_cols].skew()
        summary_conti['kurt'] = df[continuous_cols].kurt()
        summary_conti['nan_count'] = df[continuous_cols].isnull().sum()
        summary_conti['nan_share'] = summary_conti['nan_count'] / len(df)
        summary_conti['zeros_share'] = (df[continuous_cols] == 0).sum() / len(df)
        
        # 重新排列列的顺序，使其更合理
        summary_conti = summary_conti[['count', 'nan_count', 'nan_share', 'mean', 'std', 'var', 
                                       'skew', 'kurt', 'min', '25%', '50%', '75%', 'max', 'zeros_share']]
        
        # 使用style进行格式化输出
        display(summary_conti.style.format({
            'nan_share': '{:.2%}',
            'zeros_share': '{:.2%}',
            'mean': '{:.2f}',
            'std': '{:.2f}',
            'var': '{:.2f}',
            'skew': '{:.2f}',
            'kurt': '{:.2f}',
            'min': '{:.2f}',
            '25%': '{:.2f}',
            '50%': '{:.2f}',
            '75%': '{:.2f}',
            'max': '{:.2f}'
        }).background_gradient(cmap='viridis', subset=['nan_share', 'zeros_share'])
          .bar(subset=['mean', 'std'], color='#5fba7d'))

    else:
        print("\n--- 1. 无连续变量 ---\n")

    # 2. 离散变量分析
    # -------------------
    # 选择非数值类型，或唯一值数量 <= nunique_threshold 的数值类型列
    discrete_cols = [
        col for col in df.columns 
        if not pd.api.types.is_numeric_dtype(df[col]) or df[col].nunique() <= nunique_threshold
    ]

    if discrete_cols:
        print("\n--- 2. 离散/分类变量统计摘要 ---\n")
        
        summary_discrete = []
        for col in discrete_cols:
            stats = {
                '特征名 (Feature)': col,
                '数据类型 (dtype)': df[col].dtype,
                '缺失值数量 (NaNs)': df[col].isnull().sum(),
                '缺失值占比 (NaNs Share)': f"{df[col].isnull().sum() / len(df):.2%}",
                '唯一值数量 (Unique)': df[col].nunique(),
                '众数 (Mode)': df[col].mode().iloc[0] if not df[col].mode().empty else 'N/A',
            }
            summary_discrete.append(stats)
            
        summary_df_discrete = pd.DataFrame(summary_discrete).set_index('特征名 (Feature)')
        display(summary_df_discrete)

        # 打印每个离散变量的详细值分布
        print("\n--- 3. 离散/分类变量值分布详情 ---\n")
        for col in discrete_cols:
            print(f"特征: '{col}'")
            # 计算值分布并转换为DataFrame
            value_dist = df[col].value_counts(dropna=False).to_frame(name='频数 (count)')
            value_dist['占比 (share)'] = (value_dist['频数 (count)'] / len(df))
            
            # 使用Styler格式化
            display(value_dist.style.format({'占比 (share)': '{:.2%}'})
                              .bar(subset=['占比 (share)'], color='lightblue', align='zero'))
            print("-" * 30)
    else:
        print("\n--- 2. 无离散/分类变量 ---\n")

summarize_df(df)
# Out:
# --- 1. 连续变量统计摘要 ---
# <style type="text/css">
# #T_8b8e1_row0_col2, #T_8b8e1_row1_col2 {
#   background-color: #dae319;
#   color: #000000;
# }
# #T_8b8e1_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 4.2%, transparent 4.2%);
# }
# #T_8b8e1_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_8b8e1_row0_col13, #T_8b8e1_row1_col13, #T_8b8e1_row2_col13, #T_8b8e1_row3_col2, #T_8b8e1_row3_col13, #T_8b8e1_row4_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_8b8e1_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 4.2%, #5fba7d 4.2%, #5fba7d 48.0%, transparent 48.0%);
# }
# #T_8b8e1_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 63.7%, transparent 63.7%);
# }
# #T_8b8e1_row2_col2, #T_8b8e1_row4_col13 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_8b8e1_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 4.2%, #5fba7d 4.2%, #5fba7d 50.2%, transparent 50.2%);
# }
# #T_8b8e1_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 55.0%, transparent 55.0%);
# }
# #T_8b8e1_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 4.2%, #5fba7d 4.2%, #5fba7d 93.1%, transparent 93.1%);
# }
# #T_8b8e1_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 54.5%, transparent 54.5%);
# }
# #T_8b8e1_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 4.2%, #5fba7d 4.2%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_8b8e1_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #5fba7d 56.7%, transparent 56.7%);
# }
# </style>
# <table id="T_8b8e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b8e1_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_8b8e1_level0_col1" class="col_heading level0 col1" >nan_count</th>
#       <th id="T_8b8e1_level0_col2" class="col_heading level0 col2" >nan_share</th>
#       <th id="T_8b8e1_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_8b8e1_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_8b8e1_level0_col5" class="col_heading level0 col5" >var</th>
#       <th id="T_8b8e1_level0_col6" class="col_heading level0 col6" >skew</th>
#       <th id="T_8b8e1_level0_col7" class="col_heading level0 col7" >kurt</th>
#       <th id="T_8b8e1_level0_col8" class="col_heading level0 col8" >min</th>
#       <th id="T_8b8e1_level0_col9" class="col_heading level0 col9" >25%</th>
#       <th id="T_8b8e1_level0_col10" class="col_heading level0 col10" >50%</th>
#       <th id="T_8b8e1_level0_col11" class="col_heading level0 col11" >75%</th>
#       <th id="T_8b8e1_level0_col12" class="col_heading level0 col12" >max</th>
#       <th id="T_8b8e1_level0_col13" class="col_heading level0 col13" >zeros_share</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b8e1_level0_row0" class="row_heading level0 row0" >原油：常减压：独立炼厂：装置毛利：中国（周）</th>
#       <td id="T_8b8e1_row0_col0" class="data row0 col0" >344.000000</td>
#       <td id="T_8b8e1_row0_col1" class="data row0 col1" >2072</td>
#       <td id="T_8b8e1_row0_col2" class="data row0 col2" >85.76%</td>
#       <td id="T_8b8e1_row0_col3" class="data row0 col3" >-46.22</td>
#       <td id="T_8b8e1_row0_col4" class="data row0 col4" >602.89</td>
#       <td id="T_8b8e1_row0_col5" class="data row0 col5" >363478.66</td>
#       <td id="T_8b8e1_row0_col6" class="data row0 col6" >-0.20</td>
#       <td id="T_8b8e1_row0_col7" class="data row0 col7" >-0.61</td>
#       <td id="T_8b8e1_row0_col8" class="data row0 col8" >-1464.00</td>
#       <td id="T_8b8e1_row0_col9" class="data row0 col9" >-507.40</td>
#       <td id="T_8b8e1_row0_col10" class="data row0 col10" >63.50</td>
#       <td id="T_8b8e1_row0_col11" class="data row0 col11" >334.75</td>
#       <td id="T_8b8e1_row0_col12" class="data row0 col12" >1437.00</td>
#       <td id="T_8b8e1_row0_col13" class="data row0 col13" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_8b8e1_level0_row1" class="row_heading level0 row1" >原油：炼油工序：毛利：中国：主营炼厂（周）</th>
#       <td id="T_8b8e1_row1_col0" class="data row1 col0" >346.000000</td>
#       <td id="T_8b8e1_row1_col1" class="data row1 col1" >2070</td>
#       <td id="T_8b8e1_row1_col2" class="data row1 col2" >85.68%</td>
#       <td id="T_8b8e1_row1_col3" class="data row1 col3" >482.53</td>
#       <td id="T_8b8e1_row1_col4" class="data row1 col4" >383.92</td>
#       <td id="T_8b8e1_row1_col5" class="data row1 col5" >147393.82</td>
#       <td id="T_8b8e1_row1_col6" class="data row1 col6" >0.27</td>
#       <td id="T_8b8e1_row1_col7" class="data row1 col7" >0.44</td>
#       <td id="T_8b8e1_row1_col8" class="data row1 col8" >-765.94</td>
#       <td id="T_8b8e1_row1_col9" class="data row1 col9" >214.02</td>
#       <td id="T_8b8e1_row1_col10" class="data row1 col10" >460.32</td>
#       <td id="T_8b8e1_row1_col11" class="data row1 col11" >716.67</td>
#       <td id="T_8b8e1_row1_col12" class="data row1 col12" >1596.41</td>
#       <td id="T_8b8e1_row1_col13" class="data row1 col13" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_8b8e1_level0_row2" class="row_heading level0 row2" >原油：炼油工序：毛利：山东：独立炼厂（周）</th>
#       <td id="T_8b8e1_row2_col0" class="data row2 col0" >283.000000</td>
#       <td id="T_8b8e1_row2_col1" class="data row2 col1" >2133</td>
#       <td id="T_8b8e1_row2_col2" class="data row2 col2" >88.29%</td>
#       <td id="T_8b8e1_row2_col3" class="data row2 col3" >505.74</td>
#       <td id="T_8b8e1_row2_col4" class="data row2 col4" >331.38</td>
#       <td id="T_8b8e1_row2_col5" class="data row2 col5" >109813.32</td>
#       <td id="T_8b8e1_row2_col6" class="data row2 col6" >0.51</td>
#       <td id="T_8b8e1_row2_col7" class="data row2 col7" >0.25</td>
#       <td id="T_8b8e1_row2_col8" class="data row2 col8" >-184.32</td>
#       <td id="T_8b8e1_row2_col9" class="data row2 col9" >264.64</td>
#       <td id="T_8b8e1_row2_col10" class="data row2 col10" >448.10</td>
#       <td id="T_8b8e1_row2_col11" class="data row2 col11" >739.66</td>
#       <td id="T_8b8e1_row2_col12" class="data row2 col12" >1850.92</td>
#       <td id="T_8b8e1_row2_col13" class="data row2 col13" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_8b8e1_level0_row3" class="row_heading level0 row3" >柴油：裂解：价差：中国：主营销售公司（日）</th>
#       <td id="T_8b8e1_row3_col0" class="data row3 col0" >1365.000000</td>
#       <td id="T_8b8e1_row3_col1" class="data row3 col1" >1051</td>
#       <td id="T_8b8e1_row3_col2" class="data row3 col2" >43.50%</td>
#       <td id="T_8b8e1_row3_col3" class="data row3 col3" >977.87</td>
#       <td id="T_8b8e1_row3_col4" class="data row3 col4" >328.62</td>
#       <td id="T_8b8e1_row3_col5" class="data row3 col5" >107992.44</td>
#       <td id="T_8b8e1_row3_col6" class="data row3 col6" >0.56</td>
#       <td id="T_8b8e1_row3_col7" class="data row3 col7" >0.35</td>
#       <td id="T_8b8e1_row3_col8" class="data row3 col8" >61.00</td>
#       <td id="T_8b8e1_row3_col9" class="data row3 col9" >749.00</td>
#       <td id="T_8b8e1_row3_col10" class="data row3 col10" >941.00</td>
#       <td id="T_8b8e1_row3_col11" class="data row3 col11" >1149.00</td>
#       <td id="T_8b8e1_row3_col12" class="data row3 col12" >1959.00</td>
#       <td id="T_8b8e1_row3_col13" class="data row3 col13" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_8b8e1_level0_row4" class="row_heading level0 row4" >汽油：裂解：价差：中国：主营销售公司（日）</th>
#       <td id="T_8b8e1_row4_col0" class="data row4 col0" >1365.000000</td>
#       <td id="T_8b8e1_row4_col1" class="data row4 col1" >1051</td>
#       <td id="T_8b8e1_row4_col2" class="data row4 col2" >43.50%</td>
#       <td id="T_8b8e1_row4_col3" class="data row4 col3" >1054.31</td>
#       <td id="T_8b8e1_row4_col4" class="data row4 col4" >341.75</td>
#       <td id="T_8b8e1_row4_col5" class="data row4 col5" >116794.25</td>
#       <td id="T_8b8e1_row4_col6" class="data row4 col6" >-0.62</td>
#       <td id="T_8b8e1_row4_col7" class="data row4 col7" >0.41</td>
#       <td id="T_8b8e1_row4_col8" class="data row4 col8" >-125.00</td>
#       <td id="T_8b8e1_row4_col9" class="data row4 col9" >878.0
# --- 2. 离散/分类变量统计摘要 ---
#               数据类型 (dtype)  缺失值数量 (NaNs) 缺失值占比 (NaNs Share)  唯一值数量 (Unique)  \
# 特征名 (Feature)
# 指标名称                object             0              0.00%            2416
# Unnamed: 6         float64          2416            100.00%               0
# Unnamed: 7         float64          2416            100.00%               0
# Unnamed: 8         float64          2416            100.00%               0
# Unnamed: 9         float64          2416            100.00%               0
#
#                 众数 (Mode)
# 特征名 (Feature)
# 指标名称           2019/01/04
# Unnamed: 6            N/A
# Unnamed: 7            N/A
# Unnamed: 8            N/A
# Unnamed: 9            N/A
# --- 3. 离散/分类变量值分布详情 ---
#
# 特征: '指标名称'
# <style type="text/css">
# #T_683fc_row0_col1, #T_683fc_row1_col1, #T_683fc_row2_col1, #T_683fc_row3_col1, #T_683fc_row4_col1, #T_683fc_row5_col1, #T_683fc_row6_col1, #T_683fc_row7_col1, #T_683fc_row8_col1, #T_683fc_row9_col1, #T_683fc_row10_col1, #T_683fc_row11_col1, #T_683fc_row12_col1, #T_683fc_row13_col1, #T_683fc_row14_col1, #T_683fc_row15_col1, #T_683fc_row16_col1, #T_683fc_row17_col1, #T_683fc_row18_col1, #T_683fc_row19_col1, #T_683fc_row20_col1, #T_683fc_row21_col1, #T_683fc_row22_col1, #T_683fc_row23_col1, #T_683fc_row24_col1, #T_683fc_row25_col1, #T_683fc_row26_col1, #T_683fc_row27_col1, #T_683fc_row28_col1, #T_683fc_row29_col1, #T_683fc_row30_col1, #T_683fc_row31_col1, #T_683fc_row32_col1, #T_683fc_row33_col1, #T_683fc_row34_col1, #T_683fc_row35_col1, #T_683fc_row36_col1, #T_683fc_row37_col1, #T_683fc_row38_col1, #T_683fc_row39_col1, #T_683fc_row40_col1, #T_683fc_row41_col1, #T_683fc_row42_col1, #T_683fc_row43_col1, #T_683fc_row44_col1, #T_683fc_row45_col1, #T_683fc_row46_col1, #T_683fc_row47_col1, #T_683fc_row48_col1, #T_683fc_row49_col1, #T_683fc_row50_col1, #T_683fc_row51_col1, #T_683fc_row52_col1, #T_683fc_row53_col1, #T_683fc_row54_col1, #T_683fc_row55_col1, #T_683fc_row56_col1, #T_683fc_row57_col1, #T_683fc_row58_col1, #T_683fc_row59_col1, #T_683fc_row60_col1, #T_683fc_row61_col1, #T_683fc_row62_col1, #T_683fc_row63_col1, #T_683fc_row64_col1, #T_683fc_row65_col1, #T_683fc_row66_col1, #T_683fc_row67_col1, #T_683fc_row68_col1, #T_683fc_row69_col1, #T_683fc_row70_col1, #T_683fc_row71_col1, #T_683fc_row72_col1, #T_683fc_row73_col1, #T_683fc_row74_col1, #T_683fc_row75_col1, #T_683fc_row76_col1, #T_683fc_row77_col1, #T_683fc_row78_col1, #T_683fc_row79_col1, #T_683fc_row80_col1, #T_683fc_row81_col1, #T_683fc_row82_col1, #T_683fc_row83_col1, #T_683fc_row84_col1, #T_683fc_row85_col1, #T_683fc_row86_col1, #T_683fc_row87_col1, #T_683fc_row88_col1, #T_683fc_row89_col1, #T_683fc_row90_col1, #T_683fc_row91_col1, #T_683fc_row92_col1, #T_683fc_row93_col1, #T_683fc_row94_col1, #T_683fc_row95_col1, #T_683fc_row96_col1, #T_683fc_row97_col1, #T_683fc_row98_col1, #T_683fc_row99_col1, #T_683fc_row100_col1, #T_683fc_row101_col1, #T_683fc_row102_col1, #T_683fc_row103_col1, #T_683fc_row104_col1, #T_683fc_row105_col1, #T_683fc_row106_col1, #T_683fc_row107_col1, #T_683fc_row108_col1, #T_683fc_row109_col1, #T_683fc_row110_col1, #T_683fc_row111_col1, #T_683fc_row112_col1, #T_683fc_row113_col1, #T_683fc_row114_col1, #T_683fc_row115_col1, #T_683fc_row116_col1, #T_683fc_row117_col1, #T_683fc_row118_col1, #T_683fc_row119_col1, #T_683fc_row120_col1, #T_683fc_row121_col1, #T_683fc_row122_col1, #T_683fc_row123_col1, #T_683fc_row124_col1, #T_683fc_row125_col1, #T_683fc_row126_col1, #T_683fc_row127_col1, #T_683fc_row128_col1, #T_683fc_row129_col1, #T_683fc_row130_col1, #T_683fc_row131_col1, #T_683fc_row132_col1, #T_683fc_row133_col1, #T_683fc_row134_col1, #T_683fc_row135_col1, #T_683fc_row136_col1, #T_683fc_row137_col1, #T_683fc_row138_col1, #T_683fc_row139_col1, #T_683fc_row140_col1, #T_683fc_row141_col1, #T_683fc_row142_col1, #T_683fc_row143_col1, #T_683fc_row144_col1, #T_683fc_row145_col1, #T_683fc_row146_col1, #T_683fc_row147_col1, #T_683fc_row148_col1, #T_683fc_row149_col1, #T_683fc_row150_col1, #T_683fc_row151_col1, #T_683fc_row152_col1, #T_683fc_row153_col1, #T_683fc_row154_col1, #T_683fc_row155_col1, #T_683fc_row156_col1, #T_683fc_row157_col1, #T_683fc_row158_col1, #T_683fc_row159_col1, #T_683fc_row160_col1, #T_683fc_row161_col1, #T_683fc_row162_col1, #T_683fc_row163_col1, #T_683fc_row164_col1, #T_683fc_row165_col1, #T_683fc_row166_col1, #T_683fc_row167_col1, #T_683fc_row168_col1, #T_683fc_row169_col1, #T_683fc_row170_col1, #T_683fc_row171_col1, #T_683fc_row172_col1, #T_683fc_row173_col1, #T_683fc_row174_col1, #T_683fc_row175_col1, #T_683fc_row176_col1, #T_683fc_row177_col1, #T_683fc_row178_col1, #T_683fc_row179_col1, #T_683fc_row180_col1, #T_683fc_row181_col1, #T_683fc_row182_col1, #T_683fc_row183_col1, #T_683fc_row184_col1, #T_683fc_row185_col1, #T_683fc_row186_co ...
# ------------------------------
# 特征: 'Unnamed: 6'
# <style type="text/css">
# #T_a06a6_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_a06a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a06a6_level0_col0" class="col_heading level0 col0" >频数 (count)</th>
#       <th id="T_a06a6_level0_col1" class="col_heading level0 col1" >占比 (share)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Unnamed: 6</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a06a6_level0_row0" class="row_heading level0 row0" >nan</th>
#       <td id="T_a06a6_row0_col0" class="data row0 col0" >2416</td>
#       <td id="T_a06a6_row0_col1" class="data row0 col1" >100.00%</td>
#     </tr>
#   </tbody>
# </table>
# ------------------------------
# 特征: 'Unnamed: 7'
# <style type="text/css">
# #T_51f1a_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_51f1a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51f1a_level0_col0" class="col_heading level0 col0" >频数 (count)</th>
#       <th id="T_51f1a_level0_col1" class="col_heading level0 col1" >占比 (share)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Unnamed: 7</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51f1a_level0_row0" class="row_heading level0 row0" >nan</th>
#       <td id="T_51f1a_row0_col0" class="data row0 col0" >2416</td>
#       <td id="T_51f1a_row0_col1" class="data row0 col1" >100.00%</td>
#     </tr>
#   </tbody>
# </table>
# ------------------------------
# 特征: 'Unnamed: 8'
# <style type="text/css">
# #T_a8faa_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_a8faa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8faa_level0_col0" class="col_heading level0 col0" >频数 (count)</th>
#       <th id="T_a8faa_level0_col1" class="col_heading level0 col1" >占比 (share)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Unnamed: 8</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8faa_level0_row0" class="row_heading level0 row0" >nan</th>
#       <td id="T_a8faa_row0_col0" class="data row0 col0" >2416</td>
#       <td id="T_a8faa_row0_col1" class="data row0 col1" >100.00%</td>
#     </tr>
#   </tbody>
# </table>
# ------------------------------
# 特征: 'Unnamed: 9'
# <style type="text/css">
# #T_e9e01_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_e9e01">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9e01_level0_col0" class="col_heading level0 col0" >频数 (count)</th>
#       <th id="T_e9e01_level0_col1" class="col_heading level0 col1" >占比 (share)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Unnamed: 9</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9e01_level0_row0" class="row_heading level0 row0" >nan</th>
#       <td id="T_e9e01_row0_col0" class="data row0 col0" >2416</td>
#       <td id="T_e9e01_row0_col1" class="data row0 col1" >100.00%</td>
#     </tr>
#   </tbody>
# </table>
# ------------------------------

# %% [markdown]
# # 日期EDA

# %%
def eda_date_column(df, column_name=None):
    """
    column_name :
        要分析的日期列的名称。
        如果为None，函数会按以下顺序自动查找：
        1. 寻找名为 '日期' 的列。
        2. 使用第0列作为日期列。
    """
    
    # --- 1. 自动定位和预处理日期列 ---
    df_copy = df.copy()
    
    if column_name:
        if column_name not in df_copy.columns:
            print(f"错误：列 '{column_name}' 不存在于DataFrame中。")
            return
    else:
        if '日期' in df_copy.columns:
            column_name = '日期'
        else:
            column_name = df_copy.columns[0]
            print(f"提示：未指定列名，已自动选择第0列 '{column_name}' 进行分析。")

    try:
        # 转换为datetime对象，errors='coerce'会把无法转换的值设为NaT
        df_copy[column_name] = pd.to_datetime(df_copy[column_name], errors='coerce')
        # 移除转换后为空的行
        original_rows = len(df_copy)
        df_copy.dropna(subset=[column_name], inplace=True)
        if len(df_copy) < original_rows:
            print(f"提示：已移除 {original_rows - len(df_copy)} 个无法解析的日期行。")
    except Exception as e:
        print(f"错误：转换列 '{column_name}' 为日期时失败: {e}")
        return
        
    print(f"EDA for Date Column: '{column_name}'")
    print("-" * 30)
    min_date = df_copy[column_name].min().strftime('%Y-%m-%d')
    max_date = df_copy[column_name].max().strftime('%Y-%m-%d')
    print(f"时间范围: {min_date} to {max_date}")
    print(f"总记录数: {len(df_copy)}")
    
    # --- 2. 提取日期特征 ---
    s = df_copy[column_name]
    features = {
        '年份': s.dt.year,
        '月份': s.dt.month,
        '星期': s.dt.day_name(),
        '季度': s.dt.quarter,
        '周数': s.dt.isocalendar().week,
    }
    features_df = pd.DataFrame(features)
    
    # --- 3. 创建多维度可视化仪表盘 ---
    # 移除了 font='SimHei'
    sns.set_theme(style="whitegrid") 
    fig, axes = plt.subplots(2, 2, figsize=(18, 14))
    fig.suptitle(f"Date Dimension Analysis Dashboard", fontsize=20, y=0.95)
    
    # 图1: 按月统计的总体趋势
    monthly_counts = s.dt.to_period('M').value_counts().sort_index()
    monthly_counts.index = monthly_counts.index.to_timestamp()
    sns.lineplot(data=monthly_counts, ax=axes[0, 0], marker='o', label='Monthly Record Count')
    axes[0, 0].set_title('Overall Trend (Monthly Counts)')
    axes[0, 0].set_xlabel('Date')
    axes[0, 0].set_ylabel('Count')
    
    # 图2: 按年份分布
    sns.countplot(data=features_df, x='年份', hue='年份', legend=False, ax=axes[0, 1], palette='viridis')
    axes[0, 1].set_title('Yearly Distribution')
    axes[0, 1].set_xlabel('Year')
    axes[0, 1].set_ylabel('Count')
    
    # 图3: 按月份分布 (年度周期性)
    month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
                   'July', 'August', 'September', 'October', 'November', 'December']
    
    month_counts = features_df['月份'].value_counts().sort_index()
    month_counts.index = month_counts.index.map(lambda x: pd.to_datetime(f'2000-{x}-01').strftime('%B'))
    month_counts = month_counts.reindex(month_order).fillna(0)

    sns.barplot(x=month_counts.index, hue=month_counts.index, legend=False, y=month_counts.values, ax=axes[1, 0], palette='coolwarm')
    axes[1, 0].set_title('Monthly Distribution (Annual Seasonality)')
    axes[1, 0].set_xlabel('Month')
    axes[1, 0].set_ylabel('Total Count')
    
    # 图4: 按星期分布 (周度周期性)
    day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    
    day_counts = features_df['星期'].value_counts().reindex(day_order)
    
    sns.barplot(x=day_counts.index, hue=day_counts.index, legend=False, y=day_counts.values, ax=axes[1, 1], palette='plasma')
    axes[1, 1].set_title('Weekly Distribution (Weekly Seasonality)')
    axes[1, 1].set_xlabel('Day of Week')
    axes[1, 1].set_ylabel('Total Count')
    
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

    # --- 4. [优雅的可视化] 绘制日历热力图, 黄色说明有活动,灰色说明没这个日期 ---
    try:
        print("\n" + "-" * 30)
        print("Annual Activity Calendar Heatmap")
        daily_counts = s.dt.date.value_counts()
        daily_counts.index = pd.to_datetime(daily_counts.index)
        
        # 为每个年份绘制一张图
        for year in sorted(daily_counts.index.year.unique()):
            plt.figure(figsize=(18, 3))
            calmap.yearplot(daily_counts, year=year, cmap='YlGn')
            plt.suptitle(f'{year} Calendar Heatmap', fontsize=16, y=1.02)
            plt.show()
    except Exception as e:
        print(f"提示：无法绘制日历热力图，可能因为数据量或日期范围问题。错误: {e}")

eda_date_column(df)
# Out:
# 提示：未指定列名，已自动选择第0列 '指标名称' 进行分析。
# EDA for Date Column: '指标名称'
# ------------------------------
# 时间范围: 2019-01-04 to 2025-08-15
# 总记录数: 2416
# ------------------------------
# Annual Activity Calendar Heatmap

# %% [markdown]
# # 相关性分析

# %%
def encode_FE(df, cols):
    for col in cols:
        vc = df[col].value_counts(dropna=True, normalize=True).to_dict()
        df[col] = df[col].map(vc)
        df[col] = df[col].astype('float32')
    return df

def analyze_correlation(df):
    """
    自动预处理DataFrame并分析列之间的相关性。

    过程:
    1. 复制原始DataFrame以避免修改。
    2. 自动检测并转换日期/时间类型的列 (包括字符串格式) 为Unix时间戳。
    3. 对剩余的字符串(分类)列进行频率编码。
    4. 计算处理后所有数值列的相关性矩阵。

    参数:
        df (pd.DataFrame): 需要分析的输入DataFrame。

    返回:
        tuple: 一个包含两个元素的元组:
            - (pd.DataFrame): 经过预处理的全数值DataFrame。
            - (pd.DataFrame): 计算出的相关性矩阵。
    """
    print("--- 启动分析流程 ---")
    df_processed = df.copy()

    # 步骤 1: 优先处理日期/时间类型的列
    # 这样可以避免日期字符串被错误地当作普通分类变量处理
    date_cols_found = []
    for col in df_processed.columns:
        # 只尝试转换非数值类型的列
        if df_processed[col].dtype == 'object' or pd.api.types.is_datetime64_any_dtype(df_processed[col].dtype):
            try:
                # 尝试将列转换为datetime格式，无法转换的值会变为NaT
                temp_dt = pd.to_datetime(df_processed[col], errors='coerce')
                
                # 如果转换后至少有一个有效日期，则认为该列是日期列
                if not temp_dt.isnull().all():
                    print(f"检测到日期/时间列: '{col}' -> 转换为Unix时间戳")
                    # 转换为以秒为单位的Unix时间戳
                    df_processed[col] = temp_dt.astype('int64') // 10**9
                    date_cols_found.append(col)
            except (ValueError, TypeError):
                # 如果转换失败，说明不是日期列，跳过
                continue
    
    # 步骤 2: 处理剩余的字符串 (分类) 列
    # 选择所有数据类型仍为 'object' 的列
    str_cols_to_encode = df_processed.select_dtypes(include=['object']).columns.tolist()

    if str_cols_to_encode:
        print(f"检测到字符/分类列: {str_cols_to_encode} -> 进行频率编码")
        df_processed = encode_FE(df_processed, str_cols_to_encode)
    else:
        print("未找到需要频率编码的字符/分类列。")

    # 步骤 3: 计算相关性矩阵
    # 确保所有列都是数值类型
    numeric_cols = df_processed.select_dtypes(include=np.number).columns.tolist()
    if len(numeric_cols) != len(df_processed.columns):
        print("\n警告: 并非所有列都能转换为数值类型。相关性将只在数值列上计算。")
    
    print("正在计算相关性矩阵...")
    correlation_matrix = df_processed[numeric_cols].corr()
    
    print("--- 分析流程结束 ---")
    return df_processed, correlation_matrix

df_processed_result, correlation_matrix_result = analyze_correlation(df)
print(correlation_matrix_result)

print("\n\n" + "="*50)
print("      各列的 Top 5 最高相关性分析")
print("="*50)

# 遍历相关性矩阵中的每一列
for column in correlation_matrix_result.columns:
    print(f"\n--- 与 '{column}' 相关性最高的 Top 5 列 ---")
    correlations = correlation_matrix_result[column].drop(column)
    
    # 2. 找到绝对值最高的5个相关性的索引 (列名)
    #    使用 .abs() 来确保强负相关也被认为是“高”相关性
    #    使用 .nlargest(5) 来高效获取前5个值
    top_5_indices = correlations.abs().nlargest(5).index
    
    # 3. 使用这些索引从原始的相关性级数中 (包含正负号) 获取并显示结果
    top_5_values = correlations.loc[top_5_indices]
    
    # 4. 检查是否有足够的相关列可供显示
    if top_5_values.empty:
        print("没有其他列可进行相关性比较。")
    else:
        print(top_5_values)
# Out:
# --- 启动分析流程 ---
# 检测到日期/时间列: '指标名称' -> 转换为Unix时间戳
# 未找到需要频率编码的字符/分类列。
# 正在计算相关性矩阵...
# --- 分析流程结束 ---
#                             指标名称  原油：常减压：独立炼厂：装置毛利：中国（周）  \
# 指标名称                    1.000000                0.504231
# 原油：常减压：独立炼厂：装置毛利：中国（周）  0.504231                1.000000
# 原油：炼油工序：毛利：中国：主营炼厂（周）   0.322180                0.003365
# 原油：炼油工序：毛利：山东：独立炼厂（周）  -0.094861                0.321066
# 柴油：裂解：价差：中国：主营销售公司（日）  -0.363377                0.491254
# 汽油：裂解：价差：中国：主营销售公司（日）   0.125302                0.064591
# Unnamed: 6                   NaN                     NaN
# Unnamed: 7                   NaN                     NaN
# Unnamed: 8                   NaN                     NaN
# Unnamed: 9                   NaN                     NaN
#
#                         原油：炼油工序：毛利：中国：主营炼厂（周）  原油：炼油工序：毛利：山东：独立炼厂（周）  \
# 指标名称                                 0.322180              -0.094861
# 原油：常减压：独立炼厂：装置毛利：中国（周）               0.003365               0.321066
# 原油：炼油工序：毛利：中国：主营炼厂（周）                1.000000               0.212889
# 原油：炼油工序：毛利：山东：独立炼厂（周）                0.212889               1.000000
# 柴油：裂解：价差：中国：主营销售公司（日）                0.120809               0.706163
# 汽油：裂解：价差：中国：主营销售公司（日）                0.492824               0.564069
# Unnamed: 6                                NaN                    NaN
# Unnamed: 7                                NaN                    NaN
# Unnamed: 8                                NaN                    NaN
# Unnamed: 9                                NaN                    NaN
#
#                         柴油：裂解：价差：中国：主营销售公司（日）  汽油：裂解：价差：中国：主营销售公司（日）  \
# 指标名称                                -0.363377               0.125302
# 原油：常减压：独立炼厂：装置毛利：中国（周）               0.491254               0.064591
# 原油：炼油工序：毛利：中国：主营炼厂（周）                0.120809               0.492824
# 原油：炼油工序：毛利：山东：独立炼厂（周）                0.706163               0.564069
# 柴油：裂解：价差：中国：主营销售公司（日）                1.000000               0.413683
# 汽油：裂解：价差：中国：主营销售公司（日）                0.413683               1.000000
# Unnamed: 6                                NaN                    NaN
# Unnamed: 7                                NaN                    NaN
# Unnamed: 8                                NaN                    NaN
# Unnamed: 9                                NaN                    NaN
#
#                         Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9
# 指标名称                           NaN         NaN         NaN         NaN
# 原油：常减压：独立炼厂：装置毛利：中国（周）         NaN         NaN         NaN         NaN
# 原油：炼油工序：毛利：中国：主营炼厂（周）          NaN         NaN         NaN         NaN
# 原油：炼油工序：毛利：山东：独立炼厂（周）          NaN         NaN         NaN         NaN
# 柴油：裂解：价差：中国：主营销售公司（日）          NaN         NaN         NaN         NaN
# 汽油：裂解：价差：中国：主营销售公司（日）          NaN         NaN         NaN         NaN
# Unnamed: 6                     NaN         NaN         NaN         NaN
# Unnamed: 7                     NaN         NaN         NaN         NaN
# Unnamed: 8                     NaN         NaN         NaN         NaN
# Unnamed: 9                     NaN         NaN         NaN         NaN
#
#
# ==================================================
#       各列的 Top 5 最高相关性分析
# ==================================================
#
# --- 与 '指标名称' 相关性最高的 Top 5 列 ---
# 原油：常减压：独立炼厂：装置毛利：中国（周）    0.504231
# 柴油：裂解：价差：中国：主营销售公司（日）    -0.363377
# 原油：炼油工序：毛利：中国：主营炼厂（周）     0.322180
# 汽油：裂解：价差：中国：主营销售公司（日）     0.125302
# 原油：炼油工序：毛利：山东：独立炼厂（周）    -0.094861
# Name: 指标名称, dtype: float64
#
# --- 与 '原油：常减压：独立炼厂：装置毛利：中国（周）' 相关性最高的 Top 5 列 ---
# 指标名称                     0.504231
# 柴油：裂解：价差：中国：主营销售公司（日）    0.491254
# 原油：炼油工序：毛利：山东：独立炼厂（周）    0.321066
# 汽油：裂解：价差：中国：主营销售公司（日）    0.064591
# 原油：炼油工序：毛利：中国：主营炼厂（周）    0.003365
# Name: 原油：常减压：独立炼厂：装置毛利：中国（周）, dtype: float64
#
# --- 与 '原油：炼油工序：毛利：中国：主营炼厂（周）' 相关性最高的 Top 5 列 ---
# 汽油：裂解：价差：中国：主营销售公司（日）     0.492824
# 指标名称                      0.322180
# 原油：炼油工序：毛利：山东：独立炼厂（周）     0.212889
# 柴油：裂解：价差：中国：主营销售公司（日）     0.120809
# 原油：常减压：独立炼厂：装置毛利：中国（周）    0.003365
# Name: 原油：炼油工序：毛利：中国：主营炼厂（周）, dtype: float64
#
# --- 与 '原油：炼油工序：毛利：山东：独立炼厂（周）' 相关性最高的 Top 5 列 ---
# 柴油：裂解：价差：中国：主营销售公司（日）     0.706163
# 汽油：裂解：价差：中国：主营销售公司（日）     0.564069
# 原油：常减压：独立炼厂：装置毛利：中国（周）    0.321066
# 原油：炼油工序：毛利：中国：主营炼厂（周）     0.212889
# 指标名称                     -0.094861
# Name: 原油：炼油工序：毛利：山东：独立炼厂（周）, dtype: float64
#
# --- 与 '柴油：裂解：价差：中国：主营销售公司（日）' 相关性最高的 Top 5 列 ---
# 原油：炼油工序：毛利：山东：独立炼厂（周）     0.706163
# 原油：常减压：独立炼厂：装置毛利：中国（周）    0.491254
# 汽油：裂解：价差：中国：主营销售公司（日）     0.413683
# 指标名称                     -0.363377
# 原油：炼油工序：毛利：中国：主营炼厂（周）     0.120809
# Name: 柴油：裂解：价差：中国：主营销售公司（日）, dtype: float64
#
# --- 与 '汽油：裂解：价差：中国：主营销售公司（日）' 相关性最高的 Top 5 列 ---
# 原油：炼油工序：毛利：山东：独立炼厂（周）     0.564069
# 原油：炼油工序：毛利：中国：主营炼厂（周）     0.492824
# 柴油：裂解：价差：中国：主营销售公司（日）     0.413683
# 指标名称                      0.125302
# 原油：常减压：独立炼厂：装置毛利：中国（周）    0.064591
# Name: 汽油：裂解：价差：中国：主营销售公司（日）, dtype: float64
#
# --- 与 'Unnamed: 6' 相关性最高的 Top 5 列 ---
# 指标名称                     NaN
# 原油：常减压：独立炼厂：装置毛利：中国（周）   NaN
# 原油：炼油工序：毛利：中国：主营炼厂（周）    NaN
# 原油：炼油工序：毛利：山东：独立炼厂（周）    NaN
# 柴油：裂解：价差：中国：主营销售公司（日）    NaN
# Name: Unnamed: 6, dtype: float64
#
# --- 与 'Unnamed: 7' 相关性最高的 Top 5 列 ---
# 指标名称                     NaN
# 原油：常减压：独立炼厂：装置毛利：中国（周）   NaN
# 原油：炼油工序：毛利：中国：主营炼厂（周）    NaN
# 原油：炼油工序：毛利：山东：独立炼厂（周）    NaN
# 柴油：裂解：价差：中国：主营销售公司（日）    NaN
# Name: Unnamed: 7, dtype: float64
#
# --- 与 'Unnamed: 8' 相关性最高的 Top 5 列 ---
# 指标名称                     NaN
# 原油：常减压：独立炼厂：装置毛利：中国（周）   NaN
# 原油：炼油工序：毛利：中国：主营炼厂（周）    NaN
# 原油：炼油工序：毛利：山东：独立炼厂（周）    NaN
# 柴油：裂解：价差：中国：主营销售公司（日）    NaN
# Name: Unnamed: 8, dtype: float64
#
# --- 与 'Unnamed: 9' 相关性最高的 Top 5 列 ---
# 指标名称                     NaN
# 原油：常减压：独立炼厂：装置毛利：中国（周）   NaN
# 原油：炼油工序：毛利：中国：主营炼厂（周）    NaN
# 原油：炼油工序：毛利：山东：独立炼厂（周）    NaN
# 柴油：裂解：价差：中国：主营销售公司（日）    NaN
# Name: Unnamed: 9, dtype: float64
