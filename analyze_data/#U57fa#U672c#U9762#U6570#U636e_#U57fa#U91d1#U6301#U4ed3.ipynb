# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
import gc
import shutil
import calmap
from operator import itemgetter
# 需要改为你的root
root_path = '/high_perf_store3/data-lm/xiezixun/futures_predict'
data_path = os.path.join(root_path, 'data/赛题数据发布/赛道一/基本面数据/基本面数据_基金持仓.csv')

# 设置完整显示所有行列
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
    
df = pd.read_csv(data_path, low_memory=False)
df.shape
# Out:
# (1601, 10)

# %%
df.columns
# Out:
# Index(['指标名称', 'NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)',
#        'NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)', 'NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)',
#        'NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1', 'ICE:IPE:期货持仓数量:管理基金多头持仓:原油',
#        'ICE:IPE:期货持仓数量:管理基金空头持仓:原油', 'ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油',
#        'ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油', 'Unnamed: 9'],
#       dtype='object')

# %%
df.head()
# Out:
#          指标名称 NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)  \
# 0  2019/01/08                      498,716.00
# 1  2019/01/15                      498,357.00
# 2  2019/01/22                      500,895.00
# 3  2019/01/29                      499,297.00
# 4  2019/02/05                      491,870.00
#
#   NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油) NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)  \
# 0                      221,505.00                      820,328.00
# 1                      191,432.00                      811,898.00
# 2                      166,036.00                      804,057.00
# 3                      158,386.00                      804,921.00
# 4                      170,261.00                      816,098.00
#
#   NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1 ICE:IPE:期货持仓数量:管理基金多头持仓:原油  \
# 0                        221,505.00                 266,757.00
# 1                        191,432.00                 272,667.00
# 2                        166,036.00                 278,049.00
# 3                        158,386.00                 291,953.00
# 4                        170,261.00                 306,928.00
#
#   ICE:IPE:期货持仓数量:管理基金空头持仓:原油 ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油  \
# 0                101,603.00                           676,326.00
# 1                 91,566.00                           710,882.00
# 2                 68,153.00                           730,006.00
# 3                 46,261.00                           679,499.00
# 4                 60,575.00                           606,666.00
#
#   ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油  Unnamed: 9
# 0                        1,143,598.00          NaN
# 1                        1,199,304.00          NaN
# 2                        1,245,558.00          NaN
# 3                        1,225,073.00          NaN
# 4                        1,202,511.00          NaN

# %% [markdown]
# ## NAN Search

# %%
nans_df = df.isna()
nans_groups={}
for col in df.columns:
    cur_group = nans_df[col].sum()
    try:
        nans_groups[cur_group].append(col)
    except:
        nans_groups[cur_group]=[col]
del nans_df; x=gc.collect()
nans_groups = sorted(nans_groups.items(), key=itemgetter(0), reverse=True)
for k,v in nans_groups:
    print(f'{v}: NAN count = {k}, share = {round(k / len(df) * 100, 2)}%')
# Out:
# ['Unnamed: 9']: NAN count = 1601, share = 100.0%
# ['指标名称', 'NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)', 'NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)', 'NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)', 'NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1', 'ICE:IPE:期货持仓数量:管理基金多头持仓:原油', 'ICE:IPE:期货持仓数量:管理基金空头持仓:原油', 'ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油', 'ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油']: NAN count = 1254, share = 78.33%

# %% [markdown]
# # 离散值 & 连续值EDA

# %%
def summarize_df(df, nunique_threshold=100):
    """
    nunique_threshold : 一个数值型特征如果其唯一值数量低于此阈值，将被当作离散变量处理。
    """
    # 1. 连续变量分析
    # -------------------
    # 选择数值类型且唯一值数量 > nunique_threshold 的列
    continuous_cols = [
        col for col in df.columns 
        if pd.api.types.is_numeric_dtype(df[col]) and df[col].nunique() > nunique_threshold
    ]
    
    if continuous_cols:
        print("\n--- 1. 连续变量统计摘要 ---\n")
        
        # 使用describe高效计算基础统计量
        summary_conti = df[continuous_cols].describe().T
        
        # 添加更多有用的统计信息
        summary_conti['var'] = df[continuous_cols].var()
        summary_conti['skew'] = df[continuous_cols].skew()
        summary_conti['kurt'] = df[continuous_cols].kurt()
        summary_conti['nan_count'] = df[continuous_cols].isnull().sum()
        summary_conti['nan_share'] = summary_conti['nan_count'] / len(df)
        summary_conti['zeros_share'] = (df[continuous_cols] == 0).sum() / len(df)
        
        # 重新排列列的顺序，使其更合理
        summary_conti = summary_conti[['count', 'nan_count', 'nan_share', 'mean', 'std', 'var', 
                                       'skew', 'kurt', 'min', '25%', '50%', '75%', 'max', 'zeros_share']]
        
        # 使用style进行格式化输出
        display(summary_conti.style.format({
            'nan_share': '{:.2%}',
            'zeros_share': '{:.2%}',
            'mean': '{:.2f}',
            'std': '{:.2f}',
            'var': '{:.2f}',
            'skew': '{:.2f}',
            'kurt': '{:.2f}',
            'min': '{:.2f}',
            '25%': '{:.2f}',
            '50%': '{:.2f}',
            '75%': '{:.2f}',
            'max': '{:.2f}'
        }).background_gradient(cmap='viridis', subset=['nan_share', 'zeros_share'])
          .bar(subset=['mean', 'std'], color='#5fba7d'))

    else:
        print("\n--- 1. 无连续变量 ---\n")

    # 2. 离散变量分析
    # -------------------
    # 选择非数值类型，或唯一值数量 <= nunique_threshold 的数值类型列
    discrete_cols = [
        col for col in df.columns 
        if not pd.api.types.is_numeric_dtype(df[col]) or df[col].nunique() <= nunique_threshold
    ]

    if discrete_cols:
        print("\n--- 2. 离散/分类变量统计摘要 ---\n")
        
        summary_discrete = []
        for col in discrete_cols:
            stats = {
                '特征名 (Feature)': col,
                '数据类型 (dtype)': df[col].dtype,
                '缺失值数量 (NaNs)': df[col].isnull().sum(),
                '缺失值占比 (NaNs Share)': f"{df[col].isnull().sum() / len(df):.2%}",
                '唯一值数量 (Unique)': df[col].nunique(),
                '众数 (Mode)': df[col].mode().iloc[0] if not df[col].mode().empty else 'N/A',
            }
            summary_discrete.append(stats)
            
        summary_df_discrete = pd.DataFrame(summary_discrete).set_index('特征名 (Feature)')
        display(summary_df_discrete)

        # 打印每个离散变量的详细值分布
        print("\n--- 3. 离散/分类变量值分布详情 ---\n")
        for col in discrete_cols:
            print(f"特征: '{col}'")
            # 计算值分布并转换为DataFrame
            value_dist = df[col].value_counts(dropna=False).to_frame(name='频数 (count)')
            value_dist['占比 (share)'] = (value_dist['频数 (count)'] / len(df))
            
            # 使用Styler格式化
            display(value_dist.style.format({'占比 (share)': '{:.2%}'})
                              .bar(subset=['占比 (share)'], color='lightblue', align='zero'))
            print("-" * 30)
    else:
        print("\n--- 2. 无离散/分类变量 ---\n")

summarize_df(df)
# Out:
# --- 1. 无连续变量 ---
#
#
# --- 2. 离散/分类变量统计摘要 ---
#                                      数据类型 (dtype)  缺失值数量 (NaNs)  \
# 特征名 (Feature)
# 指标名称                                       object          1254
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)           object          1254
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)           object          1254
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)            object          1254
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1         object          1254
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油                 object          1254
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油                 object          1254
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油       object          1254
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油       object          1254
# Unnamed: 9                                float64          1601
#
#                                      缺失值占比 (NaNs Share)  唯一值数量 (Unique)  \
# 特征名 (Feature)
# 指标名称                                             78.33%             347
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)                 78.33%             346
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)                 78.33%             346
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)                  78.33%             346
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1               78.33%             346
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油                       78.33%             342
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油                       78.33%             342
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油             78.33%             343
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油             78.33%             343
# Unnamed: 9                                      100.00%               0
#
#                                        众数 (Mode)
# 特征名 (Feature)
# 指标名称                                  2019/01/08
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)           0.00
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)           0.00
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)            0.00
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1         0.00
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油                 0.00
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油                 0.00
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油       0.00
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油       0.00
# Unnamed: 9                                   N/A
# --- 3. 离散/分类变量值分布详情 ---
#
# 特征: '指标名称'
# <style type="text/css">
# #T_2e167_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# #T_2e167_row1_col1, #T_2e167_row2_col1, #T_2e167_row3_col1, #T_2e167_row4_col1, #T_2e167_row5_col1, #T_2e167_row6_col1, #T_2e167_row7_col1, #T_2e167_row8_col1, #T_2e167_row9_col1, #T_2e167_row10_col1, #T_2e167_row11_col1, #T_2e167_row12_col1, #T_2e167_row13_col1, #T_2e167_row14_col1, #T_2e167_row15_col1, #T_2e167_row16_col1, #T_2e167_row17_col1, #T_2e167_row18_col1, #T_2e167_row19_col1, #T_2e167_row20_col1, #T_2e167_row21_col1, #T_2e167_row22_col1, #T_2e167_row23_col1, #T_2e167_row24_col1, #T_2e167_row25_col1, #T_2e167_row26_col1, #T_2e167_row27_col1, #T_2e167_row28_col1, #T_2e167_row29_col1, #T_2e167_row30_col1, #T_2e167_row31_col1, #T_2e167_row32_col1, #T_2e167_row33_col1, #T_2e167_row34_col1, #T_2e167_row35_col1, #T_2e167_row36_col1, #T_2e167_row37_col1, #T_2e167_row38_col1, #T_2e167_row39_col1, #T_2e167_row40_col1, #T_2e167_row41_col1, #T_2e167_row42_col1, #T_2e167_row43_col1, #T_2e167_row44_col1, #T_2e167_row45_col1, #T_2e167_row46_col1, #T_2e167_row47_col1, #T_2e167_row48_col1, #T_2e167_row49_col1, #T_2e167_row50_col1, #T_2e167_row51_col1, #T_2e167_row52_col1, #T_2e167_row53_col1, #T_2e167_row54_col1, #T_2e167_row55_col1, #T_2e167_row56_col1, #T_2e167_row57_col1, #T_2e167_row58_col1, #T_2e167_row59_col1, #T_2e167_row60_col1, #T_2e167_row61_col1, #T_2e167_row62_col1, #T_2e167_row63_col1, #T_2e167_row64_col1, #T_2e167_row65_col1, #T_2e167_row66_col1, #T_2e167_row67_col1, #T_2e167_row68_col1, #T_2e167_row69_col1, #T_2e167_row70_col1, #T_2e167_row71_col1, #T_2e167_row72_col1, #T_2e167_row73_col1, #T_2e167_row74_col1, #T_2e167_row75_col1, #T_2e167_row76_col1, #T_2e167_row77_col1, #T_2e167_row78_col1, #T_2e167_row79_col1, #T_2e167_row80_col1, #T_2e167_row81_col1, #T_2e167_row82_col1, #T_2e167_row83_col1, #T_2e167_row84_col1, #T_2e167_row85_col1, #T_2e167_row86_col1, #T_2e167_row87_col1, #T_2e167_row88_col1, #T_2e167_row89_col1, #T_2e167_row90_col1, #T_2e167_row91_col1, #T_2e167_row92_col1, #T_2e167_row93_col1, #T_2e167_row94_col1, #T_2e167_row95_col1, #T_2e167_row96_col1, #T_2e167_row97_col1, #T_2e167_row98_col1, #T_2e167_row99_col1, #T_2e167_row100_col1, #T_2e167_row101_col1, #T_2e167_row102_col1, #T_2e167_row103_col1, #T_2e167_row104_col1, #T_2e167_row105_col1, #T_2e167_row106_col1, #T_2e167_row107_col1, #T_2e167_row108_col1, #T_2e167_row109_col1, #T_2e167_row110_col1, #T_2e167_row111_col1, #T_2e167_row112_col1, #T_2e167_row113_col1, #T_2e167_row114_col1, #T_2e167_row115_col1, #T_2e167_row116_col1, #T_2e167_row117_col1, #T_2e167_row118_col1, #T_2e167_row119_col1, #T_2e167_row120_col1, #T_2e167_row121_col1, #T_2e167_row122_col1, #T_2e167_row123_col1, #T_2e167_row124_col1, #T_2e167_row125_col1, #T_2e167_row126_col1, #T_2e167_row127_col1, #T_2e167_row128_col1, #T_2e167_row129_col1, #T_2e167_row130_col1, #T_2e167_row131_col1, #T_2e167_row132_col1, #T_2e167_row133_col1, #T_2e167_row134_col1, #T_2e167_row135_col1, #T_2e167_row136_col1, #T_2e167_row137_col1, #T_2e167_row138_col1, #T_2e167_row139_col1, #T_2e167_row140_col1, #T_2e167_row141_col1, #T_2e167_row142_col1, #T_2e167_row143_col1, #T_2e167_row144_col1, #T_2e167_row145_col1, #T_2e167_row146_col1, #T_2e167_row147_col1, #T_2e167_row148_col1, #T_2e167_row149_col1, #T_2e167_row150_col1, #T_2e167_row151_col1, #T_2e167_row152_col1, #T_2e167_row153_col1, #T_2e167_row154_col1, #T_2e167_row155_col1, #T_2e167_row156_col1, #T_2e167_row157_col1, #T_2e167_row158_col1, #T_2e167_row159_col1, #T_2e167_row160_col1, #T_2e167_row161_col1, #T_2e167_row162_col1, #T_2e167_row163_col1, #T_2e167_row164_col1, #T_2e167_row165_col1, #T_2e167_row166_col1, #T_2e167_row167_col1, #T_2e167_row168_col1, #T_2e167_row169_col1, #T_2e167_row170_col1, #T_2e167_row171_col1, #T_2e167_row172_col1, #T_2e167_row173_col1, #T_2e167_row174_col1, #T_2e167_row175_col1, #T_2e167_row176_col1, #T_2e167_row177_col1, #T_2e167_row178_col1, #T_2e167_row179_col1, #T_2e167_row180_col1, #T_2e167_row181_col1, #T_2e167_row182_col1, #T_2e167_row183_col1, #T_2e167_row184_col1, #T_2e167_row185_col1, #T_2e167_row186_col1, #T_2e167_row187_ ...
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_2e167">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e167_level0_col0" class="col_heading level0 col0" >频数 (count)<
# ------------------------------
# 特征: 'NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)'
# <style type="text/css">
# #T_8e976_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# #T_8e976_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.1%, transparent 50.1%);
# }
#T_7ad84_row163_col1, #T_7ad84_row164_col1, #T_7ad84_row165_col1, #T_7ad84_row166_col1, #T_7ad84_row167_col1, #T_7ad84_row168_col1, #T_7ad84_row169_col1, #T_7ad84_row170_col1, #T_7ad84_row171_col1, #T_7ad84_row172_col1, #T_7ad84_row173_col1, #T_7ad84_row174_col1, #T_7ad84_row175_col1, #T_7ad84_row176_col1, #T_7ad84_row177_col1, #T_7ad84_row178_col1, #T_7ad84_row179_col1, #T_7ad84_row180_col1, #T_7ad84_row181_col1, #T_7ad84_row182_col1, #T_7ad84_row183_col1, #T_7ad84_row184_col1, #T_7ad84_row185_col1, #T_7ad84_row186_col1, #T_7ad84_row187_col1, #T_7ad84_row18 ...
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_7ad84">
#   <thead>
#     <tr>
#       <th class="
# ------------------------------
# 特征: 'NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)'
# <style type="text/css">
# #T_f03d8_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# #T_f03d8_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.1%, transparent 50.1%);
# }
# #T_f03d8_row2_col1, #T_f03d8_row3_col1, #T_f03d8_row4_col1, #T_f03d8_row5_col1, #T_f03d8_row6_col1, #T_f03d8_row7_col1, #T_f03d8_row8_col1, #T_f03d8_row9_col1, #T_f03d8_row10_col1, #T_f03d8_row11_col1, #T_f03d8_row12_col1, #T_f03d8_row13_col1, #T_f03d8_row14_col1, #T_f03d8_row15_col1, #T_f03d8_row16_col1, #T_f03d8_row17_col1, #T_f03d8_row18_col1, #T_f03d8_row19_col1, #T_f03d8_row20_col1, #T_f03d8_row21_col1, #T_f03d8_row22_col1, #T_f03d8_row23_col1, #T_f03d8_row24_col1, #T_f03d8_row25_col1, #T_f03d8_row26_col1, #T_f03d8_row27_col1, #T_f03d8_row28_col1, #T_f03d8_row29_col1, #T_f03d8_row30_col1, #T_f03d8_row31_col1, #T_f03d8_row32_col1, #T_f03d8_row33_col1, #T_f03d8_row34_col1, #T_f03d8_row35_col1, #T_f03d8_row36_col1, #T_f03d8_row37_col1, #T_f03d8_row38_col1, #T_f03d8_row39_col1, #T_f03d8_row40_col1, #T_f03d8_row41_col1, #T_f03d8_row42_col1, #T_f03d8_row43_col1, #T_f03d8_row44_col1, #T_f03d8_row45_col1, #T_f03d8_row46_col1, #T_f03d8_row47_col1, #T_f03d8_row48_col1, #T_f03d8_row49_col1, #T_f03d8_row50_col1, #T_f03d8_row51_col1, #T_f03d8_row52_col1, #T_f03d8_row53_col1, #T_f03d8_row54_col1, #T_f03d8_row55_col1, #T_f03d8_row56_col1, #T_f03d8_row57_col1, #T_f03d8_row58_col1, #T_f03d8_row59_col1, #T_f03d8_row60_col1, #T_f03d8_row61_col1, #T_f03d8_row62_col1, #T_f03d8_row63_col1, #T_f03d8_row64_col1, #T_f03d8_row65_col1, #T_f03d8_row66_col1, #T_f03d8_row67_col1, #T_f03d8_row68_col1, #T_f03d8_row69_col1, #T_f03d8_row70_col1, #T_f03d8_row71_col1, #T_f03d8_row72_col1, #T_f03d8_row73_col1, #T_f03d8_row74_col1, #T_f03d8_row75_col1, #T_f03d8_row76_col1, #T_f03d8_row77_col1, #T_f03d8_row78_col1, #T_f03d8_row79_col1, #T_f03d8_row80_col1, #T_f03d8_row81_col1, #T_f03d8_row82_col1, #T_f03d8_row83_col1, #T_f03d8_row84_col1, #T_f03d8_row85_col1, #T_f03d8_row86_col1, #T_f03d8_row87_col1, #T_f03d8_row88_col1, #T_f03d8_row89_col1, #T_f03d8_row90_col1, #T_f03d8_row91_col1, #T_f03d8_row92_col1, #T_f03d8_row93_col1, #T_f03d8_row94_col1, #T_f03d8_row95_col1, #T_f03d8_row96_col1, #T_f03d8_row97_col1, #T_f03d8_row98_col1, #T_f03d8_row99_col1, #T_f03d8_row100_col1, #T_f03d8_row101_col1, #T_f03d8_row102_col1, #T_f03d8_row103_col1, #T_f03d8_row104_col1, #T_f03d8_row105_col1, #T_f03d8_row106_col1, #T_f03d8_row107_col1, #T_f03d8_row108_col1, #T_f03d8_row109_col1, #T_f03d8_row110_col1, #T_f03d8_row111_col1, #T_f03d8_row112_col1, #T_f03d8_row113_col1, #T_f03d8_row114_col1, #T_f03d8_row115_col1, #T_f03d8_row116_col1, #T_f03d8_row117_col1, #T_f03d8_row118_col1, #T_f03d8_row119_col1, #T_f03d8_row120_col1, #T_f03d8_row121_col1, #T_f03d8_row122_col1, #T_f03d8_row123_col1, #T_f03d8_row124_col1, #T_f03d8_row125_col1, #T_f03d8_row126_col1, #T_f03d8_row127_col1, #T_f03d8_row128_col1, #T_f03d8_row129_col1, #T_f03d8_row130_col1, #T_f03d8_row131_col1, #T_f03d8_row132_col1, #T_f03d8_row133_col1, #T_f03d8_row134_col1, #T_f03d8_row135_col1, #T_f03d8_row136_col1, #T_f03d8_row137_col1, #T_f03d8_row138_col1, #T_f03d8_row139_col1, #T_f03d8_row140_col1, #T_f03d8_row141_col1, #T_f03d8_row142_col1, #T_f03d8_row143_col1, #T_f03d8_row144_col1, #T_f03d8_row145_col1, #T_f03d8_row146_col1, #T_f03d8_row147_col1, #T_f03d8_row148_col1, #T_f03d8_row149_col1, #T_f03d8_row150_col1, #T_f03d8_row151_col1, #T_f03d8_row152_col1, #T_f03d8_row153_col1, #T_f03d8_row154_col1, #T_f03d8_row155_col1, #T_f03d8_row156_col1, #T_f03d8_row157_col1, #T_f03d8_row158_col1, #T_f03d8_row159_col1, #T_f03d8_row160_col1, #T_f03d8_row161_col1, #T_f03d8_row162_col1, #T_f03d8_row163_col1, #T_f03d8_row164_col1, #T_f03d8_row165_col1, #T_f03d8_row166_col1, #T_f03d8_row167_col1, #T_f03d8_row168_col1, #T_f03d8_row169_col1, #T_f03d8_row170_col1, #T_f03d8_row171_col1, #T_f03d8_row172_col1, #T_f03d8_row173_col1, #T_f03d8_row174_col1, #T_f03d8_row175_col1, #T_f03d8_row176_col1, #T_f03d8_row177_col1, #T_f03d8_row178_col1, #T_f03d8_row179_col1, #T_f03d8_row180_col1, #T_f03d8_row181_col1, #T_f03d8_row182_col1, #T_f03d8_row183_col1, #T_f03d8_row184_col1, #T_f03d8_row185_col1, #T_f03d8_row186_col1, #T_f03d8_row187_col1, #T_f03d8_row18 ...
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T
3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a46d3_level0_col0" clas
# ------------------------------
# 特征: 'ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油'
# <style type="text/css">
# #T_40104_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# #T_40104_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.2%, transparent 50.2%);
# }
# #T_40104_row2_col1, #T_40104_row3_col1, #T_40104_row4_col1, #T_40104_row5_col1, #T_40104_row6_col1, #T_40104_row7_col1, #T_40104_row8_col1, #T_40104_row9_col1, #T_40104_row10_col1, #T_40104_row11_col1, #T_40104_row12_col1, #T_40104_row13_col1, #T_40104_row14_col1, #T_40104_row15_col1, #T_40104_row16_col1, #T_40104_row17_col1, #T_40104_row18_col1, #T_40104_row19_col1, #T_40104_row20_col1, #T_40104_row21_col1, #T_40104_row22_col1, #T_40104_row23_col1, #T_40104_row24_col1, #T_40104_row25_col1, #T_40104_row26_col1, #T_40104_row27_col1, #T_40104_row28_col1, #T_40104_row29_col1, #T_40104_row30_col1, #T_40104_row31_col1, #T_40104_row32_col1, #T_40104_row33_col1, #T_40104_row34_col1, #T_40104_row35_col1, #T_40104_row36_col1, #T_40104_row37_col1, #T_40104_row38_col1, #T_40104_row39_col1, #T_40104_row40_col1, #T_40104_row41_col1, #T_40104_row42_col1, #T_40104_row43_col1, #T_40104_row44_col1, #T_40104_row45_col1, #T_40104_row46_col1, #T_40104_row47_col1, #T_40104_row48_col1, #T_40104_row49_col1, #T_40104_row50_col1, #T_40104_row51_col1, #T_40104_row52_col1, #T_40104_row53_col1, #T_40104_row54_col1, #T_40104_row55_col1, #T_40104_row56_col1, #T_40104_row57_col1, #T_40104_row58_col1, #T_40104_row59_col1, #T_40104_row60_col1, #T_40104_row61_col1, #T_40104_row62_col1, #T_40104_row63_col1, #T_40104_row64_col1, #T_40104_row65_col1, #T_40104_row66_col1, #T_40104_row67_col1, #T_40104_row68_col1, #T_40104_row69_col1, #T_40104_row70_col1, #T_40104_row71_col1, #T_40104_row72_col1, #T_40104_row73_col1, #T_40104_row74_col1, #T_40104_row75_col1, #T_40104_row76_col1, #T_40104_row77_col1, #T_40104_row78_col1, #T_40104_row79_col1, #T_40104_row80_col1, #T_40104_row81_col1, #T_40104_row82_col1, #T_40104_row83_col1, #T_40104_row84_col1, #T_40104_row85_col1, #T_40104_row86_col1, #T_40104_row87_col1, #T_40104_row88_col1, #T_40104_row89_col1, #T_40104_row90_col1, #T_40104_row91_col1, #T_40104_row92_col1, #T_40104_row93_col1, #T_40104_row94_col1, #T_40104_row95_col1, #T_40104_row96_col1, #T_40104_row97_col1, #T_40104_row98_col1, #T_40104_row99_col1, #T_40104_row100_col1, #T_40104_row101_col1, #T_40104_row102_col1, #T_40104_row103_col1, #T_40104_row104_col1, #T_40104_row105_col1, #T_40104_row106_col1, #T_40104_row107_col1, #T_40104_row108_col1, #T_40104_row109_col1, #T_40104_row110_col1, #T_40104_row111_col1, #T_40104_row112_col1, #T_40104_row113_col1, #T_40104_row114_col1, #T_40104_row115_col1, #T_40104_row116_col1, #T_40104_row117_col1, #T_40104_row118_col1, #T_40104_row119_col1, #T_40104_row120_col1, #T_40104_row121_col1, #T_40104_row122_col1, #T_40104_row123_col1, #T_40104_row124_col1, #T_40104_row125_col1, #T_40104_row126_col1, #T_40104_row127_col1, #T_40104_row128_col1, #T_40104_row129_col1, #T_40104_row130_col1, #T_40104_row131_col1, #T_40104_row132_col1, #T_40104_row133_col1, #T_40104_row134_col1, #T_40104_row135_col1, #T_40104_row136_col1, #T_40104_row137_col1, #T_40104_row138_col1, #T_40104_row139_col1, #T_40104_row140_col1, #T_40104_row141_col1, #T_40104_row142_col1, #T_40104_row143_col1, #T_40104_row144_col1, #T_40104_row145_col1, #T_40104_row146_col1, #T_40104_row147_col1, #T_40104_row148_col1, #T_40104_row149_col1, #T_40104_row150_col1, #T_40104_row151_col1, #T_40104_row152_col1, #T_40104_row153_col1, #T_40104_row154_col1, #T_40104_row155_col1, #T_40104_row156_col1, #T_40104_row157_col1, #T_40104_row158_col1, #T_40104_row159_col1, #T_40104_row160_col1, #T_40104_row161_col1, #T_40104_row162_col1, #T_40104_row163_col1, #T_40104_row164_col1, #T_40104_row165_col1, #T_40104_row166_col1, #T_40104_row167_col1, #T_40104_row168_col1, #T_40104_row169_col1, #T_40104_row170_col1, #T_40104_row171_col1, #T_40104_row172_col1, #T_40104_row173_col1, #T_40104_row174_col1, #T_40104_row175_col1, #T_40104_row176_col1, #T_40104_row177_col1, #T_40104_row178_col1, #T_40104_row179_col1, #T_40104_row180_col1, #T_40104_row181_col1, #T_40104_row182_col1, #T_40104_row183_col1, #T_40104_row184_col1, #T_40104_row185_col1, #T_40104_row186_col1, #T_40104_row187_col1, #T_40104_row18 ...
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_40104">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40104_level0_col0" clas
# ------------------------------
# 特征: 'Unnamed: 9'
# <style type="text/css">
# #T_85829_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_85829">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85829_level0_col0" class="col_heading level0 col0" >频数 (count)</th>
#       <th id="T_85829_level0_col1" class="col_heading level0 col1" >占比 (share)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Unnamed: 9</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85829_level0_row0" class="row_heading level0 row0" >nan</th>
#       <td id="T_85829_row0_col0" class="data row0 col0" >1601</td>
#       <td id="T_85829_row0_col1" class="data row0 col1" >100.00%</td>
#     </tr>
#   </tbody>
# </table>
# ------------------------------

# %% [markdown]
# # 日期EDA

# %%
def eda_date_column(df, column_name=None):
    """
    column_name :
        要分析的日期列的名称。
        如果为None，函数会按以下顺序自动查找：
        1. 寻找名为 '日期' 的列。
        2. 使用第0列作为日期列。
    """
    
    # --- 1. 自动定位和预处理日期列 ---
    df_copy = df.copy()
    
    if column_name:
        if column_name not in df_copy.columns:
            print(f"错误：列 '{column_name}' 不存在于DataFrame中。")
            return
    else:
        if '日期' in df_copy.columns:
            column_name = '日期'
        else:
            column_name = df_copy.columns[0]
            print(f"提示：未指定列名，已自动选择第0列 '{column_name}' 进行分析。")

    try:
        # 转换为datetime对象，errors='coerce'会把无法转换的值设为NaT
        df_copy[column_name] = pd.to_datetime(df_copy[column_name], errors='coerce')
        # 移除转换后为空的行
        original_rows = len(df_copy)
        df_copy.dropna(subset=[column_name], inplace=True)
        if len(df_copy) < original_rows:
            print(f"提示：已移除 {original_rows - len(df_copy)} 个无法解析的日期行。")
    except Exception as e:
        print(f"错误：转换列 '{column_name}' 为日期时失败: {e}")
        return
        
    print(f"EDA for Date Column: '{column_name}'")
    print("-" * 30)
    min_date = df_copy[column_name].min().strftime('%Y-%m-%d')
    max_date = df_copy[column_name].max().strftime('%Y-%m-%d')
    print(f"时间范围: {min_date} to {max_date}")
    print(f"总记录数: {len(df_copy)}")
    
    # --- 2. 提取日期特征 ---
    s = df_copy[column_name]
    features = {
        '年份': s.dt.year,
        '月份': s.dt.month,
        '星期': s.dt.day_name(),
        '季度': s.dt.quarter,
        '周数': s.dt.isocalendar().week,
    }
    features_df = pd.DataFrame(features)
    
    # --- 3. 创建多维度可视化仪表盘 ---
    # 移除了 font='SimHei'
    sns.set_theme(style="whitegrid") 
    fig, axes = plt.subplots(2, 2, figsize=(18, 14))
    fig.suptitle(f"Date Dimension Analysis Dashboard", fontsize=20, y=0.95)
    
    # 图1: 按月统计的总体趋势
    monthly_counts = s.dt.to_period('M').value_counts().sort_index()
    monthly_counts.index = monthly_counts.index.to_timestamp()
    sns.lineplot(data=monthly_counts, ax=axes[0, 0], marker='o', label='Monthly Record Count')
    axes[0, 0].set_title('Overall Trend (Monthly Counts)')
    axes[0, 0].set_xlabel('Date')
    axes[0, 0].set_ylabel('Count')
    
    # 图2: 按年份分布
    sns.countplot(data=features_df, x='年份', hue='年份', legend=False, ax=axes[0, 1], palette='viridis')
    axes[0, 1].set_title('Yearly Distribution')
    axes[0, 1].set_xlabel('Year')
    axes[0, 1].set_ylabel('Count')
    
    # 图3: 按月份分布 (年度周期性)
    month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
                   'July', 'August', 'September', 'October', 'November', 'December']
    
    month_counts = features_df['月份'].value_counts().sort_index()
    month_counts.index = month_counts.index.map(lambda x: pd.to_datetime(f'2000-{x}-01').strftime('%B'))
    month_counts = month_counts.reindex(month_order).fillna(0)

    sns.barplot(x=month_counts.index, hue=month_counts.index, legend=False, y=month_counts.values, ax=axes[1, 0], palette='coolwarm')
    axes[1, 0].set_title('Monthly Distribution (Annual Seasonality)')
    axes[1, 0].set_xlabel('Month')
    axes[1, 0].set_ylabel('Total Count')
    
    # 图4: 按星期分布 (周度周期性)
    day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    
    day_counts = features_df['星期'].value_counts().reindex(day_order)
    
    sns.barplot(x=day_counts.index, hue=day_counts.index, legend=False, y=day_counts.values, ax=axes[1, 1], palette='plasma')
    axes[1, 1].set_title('Weekly Distribution (Weekly Seasonality)')
    axes[1, 1].set_xlabel('Day of Week')
    axes[1, 1].set_ylabel('Total Count')
    
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

    # --- 4. [优雅的可视化] 绘制日历热力图, 黄色说明有活动,灰色说明没这个日期 ---
    try:
        print("\n" + "-" * 30)
        print("Annual Activity Calendar Heatmap")
        daily_counts = s.dt.date.value_counts()
        daily_counts.index = pd.to_datetime(daily_counts.index)
        
        # 为每个年份绘制一张图
        for year in sorted(daily_counts.index.year.unique()):
            plt.figure(figsize=(18, 3))
            calmap.yearplot(daily_counts, year=year, cmap='YlGn')
            plt.suptitle(f'{year} Calendar Heatmap', fontsize=16, y=1.02)
            plt.show()
    except Exception as e:
        print(f"提示：无法绘制日历热力图，可能因为数据量或日期范围问题。错误: {e}")

eda_date_column(df)
# Out:
# 提示：未指定列名，已自动选择第0列 '指标名称' 进行分析。
# 提示：已移除 1254 个无法解析的日期行。
# EDA for Date Column: '指标名称'
# ------------------------------
# 时间范围: 2019-01-08 to 2025-08-12
# 总记录数: 347
# ------------------------------
# Annual Activity Calendar Heatmap

# %% [markdown]
# # 相关性分析

# %%
def encode_FE(df, cols):
    for col in cols:
        vc = df[col].value_counts(dropna=True, normalize=True).to_dict()
        df[col] = df[col].map(vc)
        df[col] = df[col].astype('float32')
    return df

def analyze_correlation(df):
    """
    自动预处理DataFrame并分析列之间的相关性。

    过程:
    1. 复制原始DataFrame以避免修改。
    2. 自动检测并转换日期/时间类型的列 (包括字符串格式) 为Unix时间戳。
    3. 对剩余的字符串(分类)列进行频率编码。
    4. 计算处理后所有数值列的相关性矩阵。

    参数:
        df (pd.DataFrame): 需要分析的输入DataFrame。

    返回:
        tuple: 一个包含两个元素的元组:
            - (pd.DataFrame): 经过预处理的全数值DataFrame。
            - (pd.DataFrame): 计算出的相关性矩阵。
    """
    print("--- 启动分析流程 ---")
    df_processed = df.copy()

    # 步骤 1: 优先处理日期/时间类型的列
    # 这样可以避免日期字符串被错误地当作普通分类变量处理
    date_cols_found = []
    for col in df_processed.columns:
        # 只尝试转换非数值类型的列
        if df_processed[col].dtype == 'object' or pd.api.types.is_datetime64_any_dtype(df_processed[col].dtype):
            try:
                # 尝试将列转换为datetime格式，无法转换的值会变为NaT
                temp_dt = pd.to_datetime(df_processed[col], errors='coerce')
                
                # 如果转换后至少有一个有效日期，则认为该列是日期列
                if not temp_dt.isnull().all():
                    print(f"检测到日期/时间列: '{col}' -> 转换为Unix时间戳")
                    # 转换为以秒为单位的Unix时间戳
                    df_processed[col] = temp_dt.astype('int64') // 10**9
                    date_cols_found.append(col)
            except (ValueError, TypeError):
                # 如果转换失败，说明不是日期列，跳过
                continue
    
    # 步骤 2: 处理剩余的字符串 (分类) 列
    # 选择所有数据类型仍为 'object' 的列
    str_cols_to_encode = df_processed.select_dtypes(include=['object']).columns.tolist()

    if str_cols_to_encode:
        print(f"检测到字符/分类列: {str_cols_to_encode} -> 进行频率编码")
        df_processed = encode_FE(df_processed, str_cols_to_encode)
    else:
        print("未找到需要频率编码的字符/分类列。")

    # 步骤 3: 计算相关性矩阵
    # 确保所有列都是数值类型
    numeric_cols = df_processed.select_dtypes(include=np.number).columns.tolist()
    if len(numeric_cols) != len(df_processed.columns):
        print("\n警告: 并非所有列都能转换为数值类型。相关性将只在数值列上计算。")
    
    print("正在计算相关性矩阵...")
    correlation_matrix = df_processed[numeric_cols].corr()
    
    print("--- 分析流程结束 ---")
    return df_processed, correlation_matrix

df_processed_result, correlation_matrix_result = analyze_correlation(df)
print(correlation_matrix_result)

print("\n\n" + "="*50)
print("      各列的 Top 5 最高相关性分析")
print("="*50)

# 遍历相关性矩阵中的每一列
for column in correlation_matrix_result.columns:
    print(f"\n--- 与 '{column}' 相关性最高的 Top 5 列 ---")
    correlations = correlation_matrix_result[column].drop(column)
    
    # 2. 找到绝对值最高的5个相关性的索引 (列名)
    #    使用 .abs() 来确保强负相关也被认为是“高”相关性
    #    使用 .nlargest(5) 来高效获取前5个值
    top_5_indices = correlations.abs().nlargest(5).index
    
    # 3. 使用这些索引从原始的相关性级数中 (包含正负号) 获取并显示结果
    top_5_values = correlations.loc[top_5_indices]
    
    # 4. 检查是否有足够的相关列可供显示
    if top_5_values.empty:
        print("没有其他列可进行相关性比较。")
    else:
        print(top_5_values)
# Out:
# --- 启动分析流程 ---
# 检测到日期/时间列: '指标名称' -> 转换为Unix时间戳
# 检测到字符/分类列: ['NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)', 'NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)', 'NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)', 'NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1', 'ICE:IPE:期货持仓数量:管理基金多头持仓:原油', 'ICE:IPE:期货持仓数量:管理基金空头持仓:原油', 'ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油', 'ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油'] -> 进行频率编码
# 正在计算相关性矩阵...
# --- 分析流程结束 ---
#                                           指标名称  \
# 指标名称                                  1.000000
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)     -0.003045
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)     -0.003045
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)      -0.003045
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1   -0.003045
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油            0.007239
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油            0.021551
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油  0.013822
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油  0.013822
# Unnamed: 9                                 NaN
#
#                                       NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)  \
# 指标名称                                                         -0.003045
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)                              1.000000
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)                              1.000000
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)                               1.000000
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1                            1.000000
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油                                    0.068972
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油                                   -0.010016
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油                         -0.009206
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油                         -0.009206
# Unnamed: 9                                                         NaN
#
#                                       NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)  \
# 指标名称                                                         -0.003045
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)                              1.000000
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)                              1.000000
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)                               1.000000
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1                            1.000000
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油                                    0.068972
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油                                   -0.010016
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油                         -0.009206
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油                         -0.009206
# Unnamed: 9                                                         NaN
#
#                                       NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)  \
# 指标名称                                                        -0.003045
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)                             1.000000
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)                             1.000000
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)                              1.000000
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1                           1.000000
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油                                   0.068972
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油                                  -0.010016
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油                        -0.009206
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油                        -0.009206
# Unnamed: 9                                                        NaN
#
#                                       NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1  \
# 指标名称                                                           -0.003045
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)                                1.000000
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)                                1.000000
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)                                 1.000000
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1                              1.000000
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油                                      0.068972
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油                                     -0.010016
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油                           -0.009206
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油                           -0.009206
# Unnamed: 9                                                           NaN
#
#                                       ICE:IPE:期货持仓数量:管理基金多头持仓:原油  \
# 指标名称                                                    0.007239
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)                        0.068972
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)                        0.068972
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)                         0.068972
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1                      0.068972
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油                              1.000000
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油                              0.975188
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油                    0.987589
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油                    0.987589
# Unnamed: 9                                                   NaN
#
#                                       ICE:IPE:期货持仓数量:管理基金空头持仓:原油  \
# 指标名称                                                    0.021551
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)                       -0.010016
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)                       -0.010016
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)                        -0.010016
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1                     -0.010016
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油                              0.975188
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油                              1.000000
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油                    0.987589
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油                    0.987589
# Unnamed: 9                                                   NaN
#
#                                       ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油  \
# 指标名称                                                              0.013822
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)                                 -0.009206
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)                                 -0.009206
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)                                  -0.009206
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1                               -0.009206
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油                                        0.987589
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油                                        0.987589
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油                              1.000000
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油                              1.000000
# Unnamed: 9                                                             NaN
#
#                                       ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油  \
# 指标名称                                                              0.013822
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)                                 -0.009206
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)                                 -0.009206
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)                                  -0.009206
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1                               -0.009206
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油                                        0.987589
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油                                        0.987589
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油                              1.000000
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油                              1.000000
# Unnamed: 9                                                             NaN
#
#                                       Unnamed: 9
# 指标名称                                         NaN
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)             NaN
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)             NaN
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)              NaN
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1           NaN
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油                   NaN
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油                   NaN
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油         NaN
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油         NaN
# Unnamed: 9                                   NaN
#
#
# ==================================================
#       各列的 Top 5 最高相关性分析
# ==================================================
#
# --- 与 '指标名称' 相关性最高的 Top 5 列 ---
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油              0.021551
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油    0.013822
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油    0.013822
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油              0.007239
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)       -0.003045
# Name: 指标名称, dtype: float64
#
# --- 与 'NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)' 相关性最高的 Top 5 列 ---
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)      1.000000
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)       1.000000
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1    1.000000
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油            0.068972
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油           -0.010016
# Name: NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油), dtype: float64
#
# --- 与 'NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)' 相关性最高的 Top 5 列 ---
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)      1.000000
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)       1.000000
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1    1.000000
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油            0.068972
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油           -0.010016
# Name: NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油), dtype: float64
#
# --- 与 'NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)' 相关性最高的 Top 5 列 ---
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)      1.000000
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)      1.000000
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1    1.000000
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油            0.068972
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油           -0.010016
# Name: NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油), dtype: float64
#
# --- 与 'NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1' 相关性最高的 Top 5 列 ---
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)    1.000000
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)    1.000000
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)     1.000000
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油          0.068972
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油         -0.010016
# Name: NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1, dtype: float64
#
# --- 与 'ICE:IPE:期货持仓数量:管理基金多头持仓:原油' 相关性最高的 Top 5 列 ---
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油    0.987589
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油    0.987589
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油              0.975188
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)        0.068972
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)        0.068972
# Name: ICE:IPE:期货持仓数量:管理基金多头持仓:原油, dtype: float64
#
# --- 与 'ICE:IPE:期货持仓数量:管理基金空头持仓:原油' 相关性最高的 Top 5 列 ---
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油    0.987589
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油    0.987589
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油              0.975188
# 指标名称                                    0.021551
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)       -0.010016
# Name: ICE:IPE:期货持仓数量:管理基金空头持仓:原油, dtype: float64
#
# --- 与 'ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油' 相关性最高的 Top 5 列 ---
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油    1.000000
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油              0.987589
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油              0.987589
# 指标名称                                    0.013822
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)       -0.009206
# Name: ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油, dtype: float64
#
# --- 与 'ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油' 相关性最高的 Top 5 列 ---
# ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户多头持仓:原油    1.000000
# ICE:IPE:期货持仓数量:管理基金空头持仓:原油              0.987589
# ICE:IPE:期货持仓数量:管理基金多头持仓:原油              0.987589
# 指标名称                                    0.013822
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)       -0.009206
# Name: ICE:IPE:期货持仓数量:生产商/贸易商/加工商/用户空头持仓:原油, dtype: float64
#
# --- 与 'Unnamed: 9' 相关性最高的 Top 5 列 ---
# 指标名称                                 NaN
# NYMEX:持仓数量:非商业多头持仓:轻质低硫原油(WTI原油)     NaN
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油)     NaN
# NYMEX:持仓数量:商业多头持仓:轻质低硫原油(WTI原油)      NaN
# NYMEX:持仓数量:非商业空头持仓:轻质低硫原油(WTI原油).1   NaN
# Name: Unnamed: 9, dtype: float64
# /tmp/ipykernel_3972559/326313969.py:37: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   temp_dt = pd.to_datetime(df_processed[col], errors='coerce')
# /tmp/ipykernel_3972559/326313969.py:37: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   temp_dt = pd.to_datetime(df_processed[col], errors='coerce')
# /tmp/ipykernel_3972559/326313969.py:37: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   temp_dt = pd.to_datetime(df_processed[col], errors='coerce')
# /tmp/ipykernel_3972559/326313969.py:37: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   temp_dt = pd.to_datetime(df_processed[col], errors='coerce')
# /tmp/ipykernel_3972559/326313969.py:37: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   temp_dt = pd.to_datetime(df_processed[col], errors='coerce')
# /tmp/ipykernel_3972559/326313969.py:37: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   temp_dt = pd.to_datetime(df_processed[col], errors='coerce')
# /tmp/ipykernel_3972559/326313969.py:37: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   temp_dt = pd.to_datetime(df_processed[col], errors='coerce')
# /tmp/ipykernel_3972559/326313969.py:37: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   temp_dt = pd.to_datetime(df_processed[col], errors='coerce')
