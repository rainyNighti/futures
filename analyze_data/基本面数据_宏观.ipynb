# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
import gc
import shutil
import calmap
from operator import itemgetter
# 需要改为你的root
root_path = '/high_perf_store3/data-lm/xiezixun/futures_predict'
data_path = os.path.join(root_path, 'data/赛题数据发布/赛道一/基本面数据/基本面数据_宏观.csv')

# 设置完整显示所有行列
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
    
df = pd.read_csv(data_path, low_memory=False)
df.shape
# Out:
# (22492, 16)

# %%
df.columns
# Out:
# Index(['指标名称', '美国:CPI:同比', '美国:PPI:最终需求:同比:季调', '欧元区:HICP(调和CPI):当月同比',
#        '欧元区20国:PPI:当月同比', '中国:制造业PMI', '中国:工业企业:利润总额:当月同比', '中国:CPI:当月同比',
#        '中国:PPI:全部工业品:当月同比', '中国:房地产开发投资完成额:累计同比', '美国:拖欠率:信用卡消费贷款:所有商业银行:季调',
#        '美国:拖欠率:房地产贷款:所有商业银行:季调', '中国:零售渗透率:新能源乘用车', '中国:社会融资规模:当月值',
#        '中国:M1:同比', '中国:M2:同比'],
#       dtype='object')

# %%
df.head()
# Out:
#       指标名称  美国:CPI:同比  美国:PPI:最终需求:同比:季调  欧元区:HICP(调和CPI):当月同比  \
# 0  2019/01        1.6                1.9                   1.4
# 1  2019/02        1.5                1.8                   1.5
# 2  2019/03        1.9                2.0                   1.4
# 3  2019/04        2.0                2.3                   1.7
# 4  2019/05        1.8                2.1                   1.2
#
#    欧元区20国:PPI:当月同比  中国:制造业PMI  中国:工业企业:利润总额:当月同比  中国:CPI:当月同比  \
# 0              3.1       49.5                0.0          1.7
# 1              3.0       49.2                0.0          1.5
# 2              2.9       50.5               13.9          2.3
# 3              2.6       50.1               -3.7          2.5
# 4              1.7       49.4                1.1          2.7
#
#    中国:PPI:全部工业品:当月同比  中国:房地产开发投资完成额:累计同比  美国:拖欠率:信用卡消费贷款:所有商业银行:季调  \
# 0                0.1                 0.0                      0.00
# 1                0.1                11.6                      0.00
# 2                0.4                11.8                      2.54
# 3                0.9                11.9                      0.00
# 4                0.6                11.2                      0.00
#
#    美国:拖欠率:房地产贷款:所有商业银行:季调  中国:零售渗透率:新能源乘用车 中国:社会融资规模:当月值  中国:M1:同比  中国:M2:同比
# 0                    0.00              0.0    46,791.14        0.4       8.4
# 1                    0.00              0.0     9,665.13        2.0       8.0
# 2                    1.75              0.0    29,602.34        4.6       8.6
# 3                    0.00              0.0    16,709.54        2.9       8.5
# 4                    0.00              0.0    17,123.73        3.4       8.5

# %% [markdown]
# ## NAN Search

# %%
nans_df = df.isna()
nans_groups={}
for col in df.columns:
    cur_group = nans_df[col].sum()
    try:
        nans_groups[cur_group].append(col)
    except:
        nans_groups[cur_group]=[col]
del nans_df; x=gc.collect()
nans_groups = sorted(nans_groups.items(), key=itemgetter(0), reverse=True)
for k,v in nans_groups:
    print(f'{v}: NAN count = {k}, share = {round(k / len(df) * 100, 2)}%')
# Out:
# ['指标名称', '美国:CPI:同比', '美国:PPI:最终需求:同比:季调', '欧元区:HICP(调和CPI):当月同比', '欧元区20国:PPI:当月同比', '中国:制造业PMI', '中国:工业企业:利润总额:当月同比', '中国:CPI:当月同比', '中国:PPI:全部工业品:当月同比', '中国:房地产开发投资完成额:累计同比', '美国:拖欠率:信用卡消费贷款:所有商业银行:季调', '美国:拖欠率:房地产贷款:所有商业银行:季调', '中国:零售渗透率:新能源乘用车', '中国:社会融资规模:当月值', '中国:M1:同比', '中国:M2:同比']: NAN count = 22413, share = 99.65%

# %% [markdown]
# # 离散值 & 连续值EDA

# %%
def summarize_df(df, nunique_threshold=100):
    """
    nunique_threshold : 一个数值型特征如果其唯一值数量低于此阈值，将被当作离散变量处理。
    """
    # 1. 连续变量分析
    # -------------------
    # 选择数值类型且唯一值数量 > nunique_threshold 的列
    continuous_cols = [
        col for col in df.columns 
        if pd.api.types.is_numeric_dtype(df[col]) and df[col].nunique() > nunique_threshold
    ]
    
    if continuous_cols:
        print("\n--- 1. 连续变量统计摘要 ---\n")
        
        # 使用describe高效计算基础统计量
        summary_conti = df[continuous_cols].describe().T
        
        # 添加更多有用的统计信息
        summary_conti['var'] = df[continuous_cols].var()
        summary_conti['skew'] = df[continuous_cols].skew()
        summary_conti['kurt'] = df[continuous_cols].kurt()
        summary_conti['nan_count'] = df[continuous_cols].isnull().sum()
        summary_conti['nan_share'] = summary_conti['nan_count'] / len(df)
        summary_conti['zeros_share'] = (df[continuous_cols] == 0).sum() / len(df)
        
        # 重新排列列的顺序，使其更合理
        summary_conti = summary_conti[['count', 'nan_count', 'nan_share', 'mean', 'std', 'var', 
                                       'skew', 'kurt', 'min', '25%', '50%', '75%', 'max', 'zeros_share']]
        
        # 使用style进行格式化输出
        display(summary_conti.style.format({
            'nan_share': '{:.2%}',
            'zeros_share': '{:.2%}',
            'mean': '{:.2f}',
            'std': '{:.2f}',
            'var': '{:.2f}',
            'skew': '{:.2f}',
            'kurt': '{:.2f}',
            'min': '{:.2f}',
            '25%': '{:.2f}',
            '50%': '{:.2f}',
            '75%': '{:.2f}',
            'max': '{:.2f}'
        }).background_gradient(cmap='viridis', subset=['nan_share', 'zeros_share'])
          .bar(subset=['mean', 'std'], color='#5fba7d'))

    else:
        print("\n--- 1. 无连续变量 ---\n")

    # 2. 离散变量分析
    # -------------------
    # 选择非数值类型，或唯一值数量 <= nunique_threshold 的数值类型列
    discrete_cols = [
        col for col in df.columns 
        if not pd.api.types.is_numeric_dtype(df[col]) or df[col].nunique() <= nunique_threshold
    ]

    if discrete_cols:
        print("\n--- 2. 离散/分类变量统计摘要 ---\n")
        
        summary_discrete = []
        for col in discrete_cols:
            stats = {
                '特征名 (Feature)': col,
                '数据类型 (dtype)': df[col].dtype,
                '缺失值数量 (NaNs)': df[col].isnull().sum(),
                '缺失值占比 (NaNs Share)': f"{df[col].isnull().sum() / len(df):.2%}",
                '唯一值数量 (Unique)': df[col].nunique(),
                '众数 (Mode)': df[col].mode().iloc[0] if not df[col].mode().empty else 'N/A',
            }
            summary_discrete.append(stats)
            
        summary_df_discrete = pd.DataFrame(summary_discrete).set_index('特征名 (Feature)')
        display(summary_df_discrete)

        # 打印每个离散变量的详细值分布
        print("\n--- 3. 离散/分类变量值分布详情 ---\n")
        for col in discrete_cols:
            print(f"特征: '{col}'")
            # 计算值分布并转换为DataFrame
            value_dist = df[col].value_counts(dropna=False).to_frame(name='频数 (count)')
            value_dist['占比 (share)'] = (value_dist['频数 (count)'] / len(df))
            
            # 使用Styler格式化
            display(value_dist.style.format({'占比 (share)': '{:.2%}'})
                              .bar(subset=['占比 (share)'], color='lightblue', align='zero'))
            print("-" * 30)
    else:
        print("\n--- 2. 无离散/分类变量 ---\n")

summarize_df(df)
# Out:
# --- 1. 无连续变量 ---
#
#
# --- 2. 离散/分类变量统计摘要 ---
#                          数据类型 (dtype)  缺失值数量 (NaNs) 缺失值占比 (NaNs Share)  \
# 特征名 (Feature)
# 指标名称                           object         22413             99.65%
# 美国:CPI:同比                     float64         22413             99.65%
# 美国:PPI:最终需求:同比:季调             float64         22413             99.65%
# 欧元区:HICP(调和CPI):当月同比          float64         22413             99.65%
# 欧元区20国:PPI:当月同比               float64         22413             99.65%
# 中国:制造业PMI                     float64         22413             99.65%
# 中国:工业企业:利润总额:当月同比             float64         22413             99.65%
# 中国:CPI:当月同比                   float64         22413             99.65%
# 中国:PPI:全部工业品:当月同比             float64         22413             99.65%
# 中国:房地产开发投资完成额:累计同比            float64         22413             99.65%
# 美国:拖欠率:信用卡消费贷款:所有商业银行:季调      float64         22413             99.65%
# 美国:拖欠率:房地产贷款:所有商业银行:季调        float64         22413             99.65%
# 中国:零售渗透率:新能源乘用车               float64         22413             99.65%
# 中国:社会融资规模:当月值                  object         22413             99.65%
# 中国:M1:同比                      float64         22413             99.65%
# 中国:M2:同比                      float64         22413             99.65%
#
#                           唯一值数量 (Unique) 众数 (Mode)
# 特征名 (Feature)
# 指标名称                                  79   2019/01
# 美国:CPI:同比                             49       1.4
# 美国:PPI:最终需求:同比:季调                     51       1.8
# 欧元区:HICP(调和CPI):当月同比                  48       2.2
# 欧元区20国:PPI:当月同比                       69       0.0
# 中国:制造业PMI                             32      50.1
# 中国:工业企业:利润总额:当月同比                     55       0.0
# 中国:CPI:当月同比                           36       0.1
# 中国:PPI:全部工业品:当月同比                     52      -2.5
# 中国:房地产开发投资完成额:累计同比                    64       0.0
# 美国:拖欠率:信用卡消费贷款:所有商业银行:季调              26       0.0
# 美国:拖欠率:房地产贷款:所有商业银行:季调                20       0.0
# 中国:零售渗透率:新能源乘用车                        7       0.0
# 中国:社会融资规模:当月值                         79  -658.00
# 中国:M1:同比                              57       4.6
# 中国:M2:同比                              43       8.3
# --- 3. 离散/分类变量值分布详情 ---
#
# 特征: '指标名称'
# <style type="text/css">
# #T_34ca1_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# #T_34ca1_row1_col1, #T_34ca1_row2_col1, #T_34ca1_row3_col1, #T_34ca1_row4_col1, #T_34ca1_row5_col1, #T_34ca1_row6_col1, #T_34ca1_row7_col1, #T_34ca1_row8_col1, #T_34ca1_row9_col1, #T_34ca1_row10_col1, #T_34ca1_row11_col1, #T_34ca1_row12_col1, #T_34ca1_row13_col1, #T_34ca1_row14_col1, #T_34ca1_row15_col1, #T_34ca1_row16_col1, #T_34ca1_row17_col1, #T_34ca1_row18_col1, #T_34ca1_row19_col1, #T_34ca1_row20_col1, #T_34ca1_row21_col1, #T_34ca1_row22_col1, #T_34ca1_row23_col1, #T_34ca1_row24_col1, #T_34ca1_row25_col1, #T_34ca1_row26_col1, #T_34ca1_row27_col1, #T_34ca1_row28_col1, #T_34ca1_row29_col1, #T_34ca1_row30_col1, #T_34ca1_row31_col1, #T_34ca1_row32_col1, #T_34ca1_row33_col1, #T_34ca1_row34_col1, #T_34ca1_row35_col1, #T_34ca1_row36_col1, #T_34ca1_row37_col1, #T_34ca1_row38_col1, #T_34ca1_row39_col1, #T_34ca1_row40_col1, #T_34ca1_row41_col1, #T_34ca1_row42_col1, #T_34ca1_row43_col1, #T_34ca1_row44_col1, #T_34ca1_row45_col1, #T_34ca1_row46_col1, #T_34ca1_row47_col1, #T_34ca1_row48_col1, #T_34ca1_row49_col1, #T_34ca1_row50_col1, #T_34ca1_row51_col1, #T_34ca1_row52_col1, #T_34ca1_row53_col1, #T_34ca1_row54_col1, #T_34ca1_row55_col1, #T_34ca1_row56_col1, #T_34ca1_row57_col1, #T_34ca1_row58_col1, #T_34ca1_row59_col1, #T_34ca1_row60_col1, #T_34ca1_row61_col1, #T_34ca1_row62_col1, #T_34ca1_row63_col1, #T_34ca1_row64_col1, #T_34ca1_row65_col1, #T_34ca1_row66_col1, #T_34ca1_row67_col1, #T_34ca1_row68_col1, #T_34ca1_row69_col1, #T_34ca1_row70_col1, #T_34ca1_row71_col1, #T_34ca1_row72_col1, #T_34ca1_row73_col1, #T_34ca1_row74_col1, #T_34ca1_row75_col1, #T_34ca1_row76_col1, #T_34ca1_row77_col1, #T_34ca1_row78_col1, #T_34ca1_row79_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_34ca1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34ca1_level0_col0" class="col_heading level0 col0" >频数 (count)</th>
#       <th id="T_34ca1_level0_col1" class="col_heading level0 col1" >占比 (share)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >指标名称</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34ca1_level0_row0" class="row_heading level0 row0" >nan</th>
#       <td id="T_34ca1_row0_col0" class="data row0 col0" >22413</td>
#       <td id="T_34ca1_row0_col1" class="data row0 col1" >99.65%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row1" class="row_heading level0 row1" >2019/01</th>
#       <td id="T_34ca1_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_34ca1_row1_col1" class="data row1 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row2" class="row_heading level0 row2" >2019/03</th>
#       <td id="T_34ca1_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_34ca1_row2_col1" class="data row2 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row3" class="row_heading level0 row3" >2019/02</th>
#       <td id="T_34ca1_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_34ca1_row3_col1" class="data row3 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row4" class="row_heading level0 row4" >2019/05</th>
#       <td id="T_34ca1_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_34ca1_row4_col1" class="data row4 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row5" class="row_heading level0 row5" >2019/06</th>
#       <td id="T_34ca1_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_34ca1_row5_col1" class="data row5 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row6" class="row_heading level0 row6" >2019/07</th>
#       <td id="T_34ca1_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_34ca1_row6_col1" class="data row6 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row7" class="row_heading level0 row7" >2019/04</th>
#       <td id="T_34ca1_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_34ca1_row7_col1" class="data row7 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row8" class="row_heading level0 row8" >2019/09</th>
#       <td id="T_34ca1_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_34ca1_row8_col1" class="data row8 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row9" class="row_heading level0 row9" >2019/10</th>
#       <td id="T_34ca1_row9_col0" class="data row9 col0" >1</td>
#       <td id="T_34ca1_row9_col1" class="data row9 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row10" class="row_heading level0 row10" >2019/11</th>
#       <td id="T_34ca1_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_34ca1_row10_col1" class="data row10 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row11" class="row_heading level0 row11" >2019/12</th>
#       <td id="T_34ca1_row11_col0" class="data row11 col0" >1</td>
#       <td id="T_34ca1_row11_col1" class="data row11 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row12" class="row_heading level0 row12" >2020/01</th>
#       <td id="T_34ca1_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_34ca1_row12_col1" class="data row12 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row13" class="row_heading level0 row13" >2020/02</th>
#       <td id="T_34ca1_row13_col0" class="data row13 col0" >1</td>
#       <td id="T_34ca1_row13_col1" class="data row13 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row14" class="row_heading level0 row14" >2020/03</th>
#       <td id="T_34ca1_row14_col0" class="data row14 col0" >1</td>
#       <td id="T_34ca1_row14_col1" class="data row14 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row15" class="row_heading level0 row15" >2019/08</th>
#       <td id="T_34ca1_row15_col0" class="data row15 col0" >1</td>
#       <td id="T_34ca1_row15_col1" class="data row15 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row16" class="row_heading level0 row16" >2020/04</th>
#       <td id="T_34ca1_row16_col0" class="data row16 col0" >1</td>
#       <td id="T_34ca1_row16_col1" class="data row16 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row17" class="row_heading level0 row17" >2020/05</th>
#       <td id="T_34ca1_row17_col0" class="data row17 col0" >1</td>
#       <td id="T_34ca1_row17_col1" class="data row17 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row18" class="row_heading level0 row18" >2020/07</th>
#       <td id="T_34ca1_row18_col0" class="data row18 col0" >1</td>
#       <td id="T_34ca1_row18_col1" class="data row18 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row19" class="row_heading level0 row19" >2020/06</th>
#       <td id="T_34ca1_row19_col0" class="data row19 col0" >1</td>
#       <td id="T_34ca1_row19_col1" class="data row19 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row20" class="row_heading level0 row20" >2020/09</th>
#       <td id="T_34ca1_row20_col0" class="data row20 col0" >1</td>
#       <td id="T_34ca1_row20_col1" class="data row20 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row21" class="row_heading level0 row21" >2020/10</th>
#       <td id="T_34ca1_row21_col0" class="data row21 col0" >1</td>
#       <td id="T_34ca1_row21_col1" class="data row21 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row22" class="row_heading level0 row22" >2020/11</th>
#       <td id="T_34ca1_row22_col0" class="data row22 col0" >1</td>
#       <td id="T_34ca1_row22_col1" class="data row22 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_34ca1_level0_row23" class="row_heading level0 row23" >2020/08</th>
#       <td id="T_34ca1_row23_col0" class="data row23 col0" >1</td>
#       <td id="T_34ca1_row23_col1"
# ------------------------------
# 特征: '美国:CPI:同比'
# <style type="text/css">
# #T_fc501_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# #T_fc501_row1_col1, #T_fc501_row2_col1, #T_fc501_row3_col1, #T_fc501_row4_col1, #T_fc501_row5_col1, #T_fc501_row6_col1, #T_fc501_row7_col1, #T_fc501_row8_col1, #T_fc501_row9_col1, #T_fc501_row10_col1, #T_fc501_row11_col1, #T_fc501_row12_col1, #T_fc501_row13_col1, #T_fc501_row14_col1, #T_fc501_row15_col1, #T_fc501_row16_col1, #T_fc501_row17_col1, #T_fc501_row18_col1, #T_fc501_row19_col1, #T_fc501_row20_col1, #T_fc501_row21_col1, #T_fc501_row22_col1, #T_fc501_row23_col1, #T_fc501_row24_col1, #T_fc501_row25_col1, #T_fc501_row26_col1, #T_fc501_row27_col1, #T_fc501_row28_col1, #T_fc501_row29_col1, #T_fc501_row30_col1, #T_fc501_row31_col1, #T_fc501_row32_col1, #T_fc501_row33_col1, #T_fc501_row34_col1, #T_fc501_row35_col1, #T_fc501_row36_col1, #T_fc501_row37_col1, #T_fc501_row38_col1, #T_fc501_row39_col1, #T_fc501_row40_col1, #T_fc501_row41_col1, #T_fc501_row42_col1, #T_fc501_row43_col1, #T_fc501_row44_col1, #T_fc501_row45_col1, #T_fc501_row46_col1, #T_fc501_row47_col1, #T_fc501_row48_col1, #T_fc501_row49_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_fc501">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc501_level0_col0" class="col_heading level0 col0" >频数 (count)</th>
#       <th id="T_fc501_level0_col1" class="col_heading level0 col1" >占比 (share)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >美国:CPI:同比</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc501_level0_row0" class="row_heading level0 row0" >nan</th>
#       <td id="T_fc501_row0_col0" class="data row0 col0" >22413</td>
#       <td id="T_fc501_row0_col1" class="data row0 col1" >99.65%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row1" class="row_heading level0 row1" >1.800000</th>
#       <td id="T_fc501_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_fc501_row1_col1" class="data row1 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row2" class="row_heading level0 row2" >2.300000</th>
#       <td id="T_fc501_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_fc501_row2_col1" class="data row2 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row3" class="row_heading level0 row3" >1.400000</th>
#       <td id="T_fc501_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_fc501_row3_col1" class="data row3 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row4" class="row_heading level0 row4" >2.700000</th>
#       <td id="T_fc501_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_fc501_row4_col1" class="data row4 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row5" class="row_heading level0 row5" >3.000000</th>
#       <td id="T_fc501_row5_col0" class="data row5 col0" >3</td>
#       <td id="T_fc501_row5_col1" class="data row5 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row6" class="row_heading level0 row6" >2.400000</th>
#       <td id="T_fc501_row6_col0" class="data row6 col0" >3</td>
#       <td id="T_fc501_row6_col1" class="data row6 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row7" class="row_heading level0 row7" >3.200000</th>
#       <td id="T_fc501_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_fc501_row7_col1" class="data row7 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row8" class="row_heading level0 row8" >5.400000</th>
#       <td id="T_fc501_row8_col0" class="data row8 col0" >3</td>
#       <td id="T_fc501_row8_col1" class="data row8 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row9" class="row_heading level0 row9" >1.700000</th>
#       <td id="T_fc501_row9_col0" class="data row9 col0" >3</td>
#       <td id="T_fc501_row9_col1" class="data row9 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row10" class="row_heading level0 row10" >5.000000</th>
#       <td id="T_fc501_row10_col0" class="data row10 col0" >2</td>
#       <td id="T_fc501_row10_col1" class="data row10 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row11" class="row_heading level0 row11" >8.300000</th>
#       <td id="T_fc501_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_fc501_row11_col1" class="data row11 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row12" class="row_heading level0 row12" >1.500000</th>
#       <td id="T_fc501_row12_col0" class="data row12 col0" >2</td>
#       <td id="T_fc501_row12_col1" class="data row12 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row13" class="row_heading level0 row13" >1.600000</th>
#       <td id="T_fc501_row13_col0" class="data row13 col0" >2</td>
#       <td id="T_fc501_row13_col1" class="data row13 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row14" class="row_heading level0 row14" >1.200000</th>
#       <td id="T_fc501_row14_col0" class="data row14 col0" >2</td>
#       <td id="T_fc501_row14_col1" class="data row14 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row15" class="row_heading level0 row15" >2.600000</th>
#       <td id="T_fc501_row15_col0" class="data row15 col0" >2</td>
#       <td id="T_fc501_row15_col1" class="data row15 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row16" class="row_heading level0 row16" >2.500000</th>
#       <td id="T_fc501_row16_col0" class="data row16 col0" >2</td>
#       <td id="T_fc501_row16_col1" class="data row16 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row17" class="row_heading level0 row17" >3.700000</th>
#       <td id="T_fc501_row17_col0" class="data row17 col0" >2</td>
#       <td id="T_fc501_row17_col1" class="data row17 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row18" class="row_heading level0 row18" >2.900000</th>
#       <td id="T_fc501_row18_col0" class="data row18 col0" >2</td>
#       <td id="T_fc501_row18_col1" class="data row18 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row19" class="row_heading level0 row19" >3.100000</th>
#       <td id="T_fc501_row19_col0" class="data row19 col0" >2</td>
#       <td id="T_fc501_row19_col1" class="data row19 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row20" class="row_heading level0 row20" >3.400000</th>
#       <td id="T_fc501_row20_col0" class="data row20 col0" >2</td>
#       <td id="T_fc501_row20_col1" class="data row20 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row21" class="row_heading level0 row21" >8.500000</th>
#       <td id="T_fc501_row21_col0" class="data row21 col0" >2</td>
#       <td id="T_fc501_row21_col1" class="data row21 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row22" class="row_heading level0 row22" >4.200000</th>
#       <td id="T_fc501_row22_col0" class="data row22 col0" >1</td>
#       <td id="T_fc501_row22_col1" class="data row22 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row23" class="row_heading level0 row23" >2.000000</th>
#       <td id="T_fc501_row23_col0" class="data row23 col0" >1</td>
#       <td id="T_fc501_row23_col1" class="data row23 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row24" class="row_heading level0 row24" >2.100000</th>
#       <td id="T_fc501_row24_col0" class="data row24 col0" >1</td>
#       <td id="T_fc501_row24_col1" class="data row24 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row25" class="row_heading level0 row25" >0.300000</th>
#       <td id="T_fc501_row25_col0" class="data row25 col0" >1</td>
#       <td id="T_fc501_row25_col1" class="data row25 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_fc501_level0_row26" class="row_heading level0 row26"
# ------------------------------
# 特征: '美国:PPI:最终需求:同比:季调'
# <style type="text/css">
# #T_c3387_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# #T_c3387_row1_col1, #T_c3387_row2_col1, #T_c3387_row3_col1, #T_c3387_row4_col1, #T_c3387_row5_col1, #T_c3387_row6_col1, #T_c3387_row7_col1, #T_c3387_row8_col1, #T_c3387_row9_col1, #T_c3387_row10_col1, #T_c3387_row11_col1, #T_c3387_row12_col1, #T_c3387_row13_col1, #T_c3387_row14_col1, #T_c3387_row15_col1, #T_c3387_row16_col1, #T_c3387_row17_col1, #T_c3387_row18_col1, #T_c3387_row19_col1, #T_c3387_row20_col1, #T_c3387_row21_col1, #T_c3387_row22_col1, #T_c3387_row23_col1, #T_c3387_row24_col1, #T_c3387_row25_col1, #T_c3387_row26_col1, #T_c3387_row27_col1, #T_c3387_row28_col1, #T_c3387_row29_col1, #T_c3387_row30_col1, #T_c3387_row31_col1, #T_c3387_row32_col1, #T_c3387_row33_col1, #T_c3387_row34_col1, #T_c3387_row35_col1, #T_c3387_row36_col1, #T_c3387_row37_col1, #T_c3387_row38_col1, #T_c3387_row39_col1, #T_c3387_row40_col1, #T_c3387_row41_col1, #T_c3387_row42_col1, #T_c3387_row43_col1, #T_c3387_row44_col1, #T_c3387_row45_col1, #T_c3387_row46_col1, #T_c3387_row47_col1, #T_c3387_row48_col1, #T_c3387_row49_col1, #T_c3387_row50_col1, #T_c3387_row51_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_c3387">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3387_level0_col0" class="col_heading level0 col0" >频数 (count)</th>
#       <th id="T_c3387_level0_col1" class="col_heading level0 col1" >占比 (share)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >美国:PPI:最终需求:同比:季调</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3387_level0_row0" class="row_heading level0 row0" >nan</th>
#       <td id="T_c3387_row0_col0" class="data row0 col0" >22413</td>
#       <td id="T_c3387_row0_col1" class="data row0 col1" >99.65%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row1" class="row_heading level0 row1" >1.800000</th>
#       <td id="T_c3387_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_c3387_row1_col1" class="data row1 col1" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row2" class="row_heading level0 row2" >2.300000</th>
#       <td id="T_c3387_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_c3387_row2_col1" class="data row2 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row3" class="row_heading level0 row3" >1.900000</th>
#       <td id="T_c3387_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_c3387_row3_col1" class="data row3 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row4" class="row_heading level0 row4" >1.200000</th>
#       <td id="T_c3387_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_c3387_row4_col1" class="data row4 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row5" class="row_heading level0 row5" >1.100000</th>
#       <td id="T_c3387_row5_col0" class="data row5 col0" >3</td>
#       <td id="T_c3387_row5_col1" class="data row5 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row6" class="row_heading level0 row6" >0.800000</th>
#       <td id="T_c3387_row6_col0" class="data row6 col0" >3</td>
#       <td id="T_c3387_row6_col1" class="data row6 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row7" class="row_heading level0 row7" >2.100000</th>
#       <td id="T_c3387_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_c3387_row7_col1" class="data row7 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row8" class="row_heading level0 row8" >2.400000</th>
#       <td id="T_c3387_row8_col0" class="data row8 col0" >3</td>
#       <td id="T_c3387_row8_col1" class="data row8 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row9" class="row_heading level0 row9" >1.000000</th>
#       <td id="T_c3387_row9_col0" class="data row9 col0" >2</td>
#       <td id="T_c3387_row9_col1" class="data row9 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row10" class="row_heading level0 row10" >1.400000</th>
#       <td id="T_c3387_row10_col0" class="data row10 col0" >2</td>
#       <td id="T_c3387_row10_col1" class="data row10 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row11" class="row_heading level0 row11" >2.000000</th>
#       <td id="T_c3387_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_c3387_row11_col1" class="data row11 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row12" class="row_heading level0 row12" >10.200000</th>
#       <td id="T_c3387_row12_col0" class="data row12 col0" >2</td>
#       <td id="T_c3387_row12_col1" class="data row12 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row13" class="row_heading level0 row13" >7.400000</th>
#       <td id="T_c3387_row13_col0" class="data row13 col0" >2</td>
#       <td id="T_c3387_row13_col1" class="data row13 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row14" class="row_heading level0 row14" >2.800000</th>
#       <td id="T_c3387_row14_col0" class="data row14 col0" >2</td>
#       <td id="T_c3387_row14_col1" class="data row14 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row15" class="row_heading level0 row15" >11.000000</th>
#       <td id="T_c3387_row15_col0" class="data row15 col0" >2</td>
#       <td id="T_c3387_row15_col1" class="data row15 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row16" class="row_heading level0 row16" >6.400000</th>
#       <td id="T_c3387_row16_col0" class="data row16 col0" >2</td>
#       <td id="T_c3387_row16_col1" class="data row16 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row17" class="row_heading level0 row17" >2.900000</th>
#       <td id="T_c3387_row17_col0" class="data row17 col0" >2</td>
#       <td id="T_c3387_row17_col1" class="data row17 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row18" class="row_heading level0 row18" >0.300000</th>
#       <td id="T_c3387_row18_col0" class="data row18 col0" >2</td>
#       <td id="T_c3387_row18_col1" class="data row18 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row19" class="row_heading level0 row19" >1.600000</th>
#       <td id="T_c3387_row19_col0" class="data row19 col0" >2</td>
#       <td id="T_c3387_row19_col1" class="data row19 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row20" class="row_heading level0 row20" >1.700000</th>
#       <td id="T_c3387_row20_col0" class="data row20 col0" >1</td>
#       <td id="T_c3387_row20_col1" class="data row20 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row21" class="row_heading level0 row21" >0.500000</th>
#       <td id="T_c3387_row21_col0" class="data row21 col0" >1</td>
#       <td id="T_c3387_row21_col1" class="data row21 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row22" class="row_heading level0 row22" >0.400000</th>
#       <td id="T_c3387_row22_col0" class="data row22 col0" >1</td>
#       <td id="T_c3387_row22_col1" class="data row22 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row23" class="row_heading level0 row23" >-0.200000</th>
#       <td id="T_c3387_row23_col0" class="data row23 col0" >1</td>
#       <td id="T_c3387_row23_col1" class="data row23 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row24" class="row_heading level0 row24" >-0.600000</th>
#       <td id="T_c3387_row24_col0" class="data row24 col0" >1</td>
#       <td id="T_c3387_row24_col1" class="data row24 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_c3387_level0_row25" class="row_heading level0 row25" >-0.300000</th>
#       <td id="T_c3387_row25_col0" class="data row25 col0" >1</td>
#       <td id="T_c3387_row25_col1" class="data row25 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id=
# ------------------------------
# 特征: '欧元区:HICP(调和CPI):当月同比'
# <style type="text/css">
# #T_5f0f4_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# #T_5f0f4_row1_col1, #T_5f0f4_row2_col1, #T_5f0f4_row3_col1, #T_5f0f4_row4_col1, #T_5f0f4_row5_col1, #T_5f0f4_row6_col1, #T_5f0f4_row7_col1, #T_5f0f4_row8_col1, #T_5f0f4_row9_col1, #T_5f0f4_row10_col1, #T_5f0f4_row11_col1, #T_5f0f4_row12_col1, #T_5f0f4_row13_col1, #T_5f0f4_row14_col1, #T_5f0f4_row15_col1, #T_5f0f4_row16_col1, #T_5f0f4_row17_col1, #T_5f0f4_row18_col1, #T_5f0f4_row19_col1, #T_5f0f4_row20_col1, #T_5f0f4_row21_col1, #T_5f0f4_row22_col1, #T_5f0f4_row23_col1, #T_5f0f4_row24_col1, #T_5f0f4_row25_col1, #T_5f0f4_row26_col1, #T_5f0f4_row27_col1, #T_5f0f4_row28_col1, #T_5f0f4_row29_col1, #T_5f0f4_row30_col1, #T_5f0f4_row31_col1, #T_5f0f4_row32_col1, #T_5f0f4_row33_col1, #T_5f0f4_row34_col1, #T_5f0f4_row35_col1, #T_5f0f4_row36_col1, #T_5f0f4_row37_col1, #T_5f0f4_row38_col1, #T_5f0f4_row39_col1, #T_5f0f4_row40_col1, #T_5f0f4_row41_col1, #T_5f0f4_row42_col1, #T_5f0f4_row43_col1, #T_5f0f4_row44_col1, #T_5f0f4_row45_col1, #T_5f0f4_row46_col1, #T_5f0f4_row47_col1, #T_5f0f4_row48_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_5f0f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f0f4_level0_col0" class="col_heading level0 col0" >频数 (count)</th>
#       <th id="T_5f0f4_level0_col1" class="col_heading level0 col1" >占比 (share)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >欧元区:HICP(调和CPI):当月同比</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f0f4_level0_row0" class="row_heading level0 row0" >nan</th>
#       <td id="T_5f0f4_row0_col0" class="data row0 col0" >22413</td>
#       <td id="T_5f0f4_row0_col1" class="data row0 col1" >99.65%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row1" class="row_heading level0 row1" >2.200000</th>
#       <td id="T_5f0f4_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_5f0f4_row1_col1" class="data row1 col1" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row2" class="row_heading level0 row2" >2.400000</th>
#       <td id="T_5f0f4_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_5f0f4_row2_col1" class="data row2 col1" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row3" class="row_heading level0 row3" >-0.300000</th>
#       <td id="T_5f0f4_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_5f0f4_row3_col1" class="data row3 col1" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row4" class="row_heading level0 row4" >2.000000</th>
#       <td id="T_5f0f4_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_5f0f4_row4_col1" class="data row4 col1" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row5" class="row_heading level0 row5" >2.600000</th>
#       <td id="T_5f0f4_row5_col0" class="data row5 col0" >3</td>
#       <td id="T_5f0f4_row5_col1" class="data row5 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row6" class="row_heading level0 row6" >1.400000</th>
#       <td id="T_5f0f4_row6_col0" class="data row6 col0" >3</td>
#       <td id="T_5f0f4_row6_col1" class="data row6 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row7" class="row_heading level0 row7" >1.300000</th>
#       <td id="T_5f0f4_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_5f0f4_row7_col1" class="data row7 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row8" class="row_heading level0 row8" >1.000000</th>
#       <td id="T_5f0f4_row8_col0" class="data row8 col0" >3</td>
#       <td id="T_5f0f4_row8_col1" class="data row8 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row9" class="row_heading level0 row9" >0.900000</th>
#       <td id="T_5f0f4_row9_col0" class="data row9 col0" >2</td>
#       <td id="T_5f0f4_row9_col1" class="data row9 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row10" class="row_heading level0 row10" >1.900000</th>
#       <td id="T_5f0f4_row10_col0" class="data row10 col0" >2</td>
#       <td id="T_5f0f4_row10_col1" class="data row10 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row11" class="row_heading level0 row11" >7.400000</th>
#       <td id="T_5f0f4_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_5f0f4_row11_col1" class="data row11 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row12" class="row_heading level0 row12" >2.900000</th>
#       <td id="T_5f0f4_row12_col0" class="data row12 col0" >2</td>
#       <td id="T_5f0f4_row12_col1" class="data row12 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row13" class="row_heading level0 row13" >0.300000</th>
#       <td id="T_5f0f4_row13_col0" class="data row13 col0" >2</td>
#       <td id="T_5f0f4_row13_col1" class="data row13 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row14" class="row_heading level0 row14" >0.700000</th>
#       <td id="T_5f0f4_row14_col0" class="data row14 col0" >2</td>
#       <td id="T_5f0f4_row14_col1" class="data row14 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row15" class="row_heading level0 row15" >1.200000</th>
#       <td id="T_5f0f4_row15_col0" class="data row15 col0" >2</td>
#       <td id="T_5f0f4_row15_col1" class="data row15 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row16" class="row_heading level0 row16" >1.700000</th>
#       <td id="T_5f0f4_row16_col0" class="data row16 col0" >2</td>
#       <td id="T_5f0f4_row16_col1" class="data row16 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row17" class="row_heading level0 row17" >8.600000</th>
#       <td id="T_5f0f4_row17_col0" class="data row17 col0" >2</td>
#       <td id="T_5f0f4_row17_col1" class="data row17 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row18" class="row_heading level0 row18" >2.500000</th>
#       <td id="T_5f0f4_row18_col0" class="data row18 col0" >2</td>
#       <td id="T_5f0f4_row18_col1" class="data row18 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row19" class="row_heading level0 row19" >1.600000</th>
#       <td id="T_5f0f4_row19_col0" class="data row19 col0" >1</td>
#       <td id="T_5f0f4_row19_col1" class="data row19 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row20" class="row_heading level0 row20" >0.100000</th>
#       <td id="T_5f0f4_row20_col0" class="data row20 col0" >1</td>
#       <td id="T_5f0f4_row20_col1" class="data row20 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row21" class="row_heading level0 row21" >1.500000</th>
#       <td id="T_5f0f4_row21_col0" class="data row21 col0" >1</td>
#       <td id="T_5f0f4_row21_col1" class="data row21 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row22" class="row_heading level0 row22" >0.800000</th>
#       <td id="T_5f0f4_row22_col0" class="data row22 col0" >1</td>
#       <td id="T_5f0f4_row22_col1" class="data row22 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row23" class="row_heading level0 row23" >0.400000</th>
#       <td id="T_5f0f4_row23_col0" class="data row23 col0" >1</td>
#       <td id="T_5f0f4_row23_col1" class="data row23 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row24" class="row_heading level0 row24" >-0.200000</th>
#       <td id="T_5f0f4_row24_col0" class="data row24 col0" >1</td>
#       <td id="T_5f0f4_row24_col1" class="data row24 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row25" class="row_heading level0 row25" >5.900000</th>
#       <td id="T_5f0f4_row25_col0" class="data row25 col0" >1</td>
#       <td id="T_5f0f4_row25_col1" class="data row25 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_5f0f4_level0_row26" class="row_heading level0 row26" >5.1000
# ------------------------------
# 特征: '欧元区20国:PPI:当月同比'
# <style type="text/css">
# #T_0e01d_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# #T_0e01d_row1_col1, #T_0e01d_row2_col1, #T_0e01d_row3_col1, #T_0e01d_row4_col1, #T_0e01d_row5_col1, #T_0e01d_row6_col1, #T_0e01d_row7_col1, #T_0e01d_row8_col1, #T_0e01d_row9_col1, #T_0e01d_row10_col1, #T_0e01d_row11_col1, #T_0e01d_row12_col1, #T_0e01d_row13_col1, #T_0e01d_row14_col1, #T_0e01d_row15_col1, #T_0e01d_row16_col1, #T_0e01d_row17_col1, #T_0e01d_row18_col1, #T_0e01d_row19_col1, #T_0e01d_row20_col1, #T_0e01d_row21_col1, #T_0e01d_row22_col1, #T_0e01d_row23_col1, #T_0e01d_row24_col1, #T_0e01d_row25_col1, #T_0e01d_row26_col1, #T_0e01d_row27_col1, #T_0e01d_row28_col1, #T_0e01d_row29_col1, #T_0e01d_row30_col1, #T_0e01d_row31_col1, #T_0e01d_row32_col1, #T_0e01d_row33_col1, #T_0e01d_row34_col1, #T_0e01d_row35_col1, #T_0e01d_row36_col1, #T_0e01d_row37_col1, #T_0e01d_row38_col1, #T_0e01d_row39_col1, #T_0e01d_row40_col1, #T_0e01d_row41_col1, #T_0e01d_row42_col1, #T_0e01d_row43_col1, #T_0e01d_row44_col1, #T_0e01d_row45_col1, #T_0e01d_row46_col1, #T_0e01d_row47_col1, #T_0e01d_row48_col1, #T_0e01d_row49_col1, #T_0e01d_row50_col1, #T_0e01d_row51_col1, #T_0e01d_row52_col1, #T_0e01d_row53_col1, #T_0e01d_row54_col1, #T_0e01d_row55_col1, #T_0e01d_row56_col1, #T_0e01d_row57_col1, #T_0e01d_row58_col1, #T_0e01d_row59_col1, #T_0e01d_row60_col1, #T_0e01d_row61_col1, #T_0e01d_row62_col1, #T_0e01d_row63_col1, #T_0e01d_row64_col1, #T_0e01d_row65_col1, #T_0e01d_row66_col1, #T_0e01d_row67_col1, #T_0e01d_row68_col1, #T_0e01d_row69_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_0e01d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e01d_level0_col0" class="col_heading level0 col0" >频数 (count)</th>
#       <th id="T_0e01d_level0_col1" class="col_heading level0 col1" >占比 (share)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >欧元区20国:PPI:当月同比</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e01d_level0_row0" class="row_heading level0 row0" >nan</th>
#       <td id="T_0e01d_row0_col0" class="data row0 col0" >22413</td>
#       <td id="T_0e01d_row0_col1" class="data row0 col1" >99.65%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row1" class="row_heading level0 row1" >0.000000</th>
#       <td id="T_0e01d_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_0e01d_row1_col1" class="data row1 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row2" class="row_heading level0 row2" >1.700000</th>
#       <td id="T_0e01d_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_0e01d_row2_col1" class="data row2 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row3" class="row_heading level0 row3" >-1.200000</th>
#       <td id="T_0e01d_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_0e01d_row3_col1" class="data row3 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row4" class="row_heading level0 row4" >3.100000</th>
#       <td id="T_0e01d_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_0e01d_row4_col1" class="data row4 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row5" class="row_heading level0 row5" >0.700000</th>
#       <td id="T_0e01d_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_0e01d_row5_col1" class="data row5 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row6" class="row_heading level0 row6" >-2.100000</th>
#       <td id="T_0e01d_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_0e01d_row6_col1" class="data row6 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row7" class="row_heading level0 row7" >-0.900000</th>
#       <td id="T_0e01d_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_0e01d_row7_col1" class="data row7 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row8" class="row_heading level0 row8" >-7.800000</th>
#       <td id="T_0e01d_row8_col0" class="data row8 col0" >2</td>
#       <td id="T_0e01d_row8_col1" class="data row8 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row9" class="row_heading level0 row9" >-0.800000</th>
#       <td id="T_0e01d_row9_col0" class="data row9 col0" >2</td>
#       <td id="T_0e01d_row9_col1" class="data row9 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row10" class="row_heading level0 row10" >2.900000</th>
#       <td id="T_0e01d_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_0e01d_row10_col1" class="data row10 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row11" class="row_heading level0 row11" >2.600000</th>
#       <td id="T_0e01d_row11_col0" class="data row11 col0" >1</td>
#       <td id="T_0e01d_row11_col1" class="data row11 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row12" class="row_heading level0 row12" >3.000000</th>
#       <td id="T_0e01d_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_0e01d_row12_col1" class="data row12 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row13" class="row_heading level0 row13" >-2.000000</th>
#       <td id="T_0e01d_row13_col0" class="data row13 col0" >1</td>
#       <td id="T_0e01d_row13_col1" class="data row13 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row14" class="row_heading level0 row14" >-2.800000</th>
#       <td id="T_0e01d_row14_col0" class="data row14 col0" >1</td>
#       <td id="T_0e01d_row14_col1" class="data row14 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row15" class="row_heading level0 row15" >-4.600000</th>
#       <td id="T_0e01d_row15_col0" class="data row15 col0" >1</td>
#       <td id="T_0e01d_row15_col1" class="data row15 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row16" class="row_heading level0 row16" >-3.700000</th>
#       <td id="T_0e01d_row16_col0" class="data row16 col0" >1</td>
#       <td id="T_0e01d_row16_col1" class="data row16 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row17" class="row_heading level0 row17" >-5.000000</th>
#       <td id="T_0e01d_row17_col0" class="data row17 col0" >1</td>
#       <td id="T_0e01d_row17_col1" class="data row17 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row18" class="row_heading level0 row18" >-3.200000</th>
#       <td id="T_0e01d_row18_col0" class="data row18 col0" >1</td>
#       <td id="T_0e01d_row18_col1" class="data row18 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row19" class="row_heading level0 row19" >-2.600000</th>
#       <td id="T_0e01d_row19_col0" class="data row19 col0" >1</td>
#       <td id="T_0e01d_row19_col1" class="data row19 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row20" class="row_heading level0 row20" >-1.400000</th>
#       <td id="T_0e01d_row20_col0" class="data row20 col0" >1</td>
#       <td id="T_0e01d_row20_col1" class="data row20 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row21" class="row_heading level0 row21" >-1.500000</th>
#       <td id="T_0e01d_row21_col0" class="data row21 col0" >1</td>
#       <td id="T_0e01d_row21_col1" class="data row21 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row22" class="row_heading level0 row22" >-1.100000</th>
#       <td id="T_0e01d_row22_col0" class="data row22 col0" >1</td>
#       <td id="T_0e01d_row22_col1" class="data row22 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row23" class="row_heading level0 row23" >0.900000</th>
#       <td id="T_0e01d_row23_col0" class="data row23 col0" >1</td>
#       <td id="T_0e01d_row23_col1" class="data row23 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0e01d_level0_row24" class="row_heading level0 row24" >2.000000</th>
#       <td id="T_0e01d
# ------------------------------
# 特征: '中国:制造业PMI'
# <style type="text/css">
# #T_a9eca_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# #T_a9eca_row1_col1, #T_a9eca_row2_col1, #T_a9eca_row3_col1, #T_a9eca_row4_col1, #T_a9eca_row5_col1, #T_a9eca_row6_col1, #T_a9eca_row7_col1, #T_a9eca_row8_col1, #T_a9eca_row9_col1, #T_a9eca_row10_col1, #T_a9eca_row11_col1, #T_a9eca_row12_col1, #T_a9eca_row13_col1, #T_a9eca_row14_col1, #T_a9eca_row15_col1, #T_a9eca_row16_col1, #T_a9eca_row17_col1, #T_a9eca_row18_col1, #T_a9eca_row19_col1, #T_a9eca_row20_col1, #T_a9eca_row21_col1, #T_a9eca_row22_col1, #T_a9eca_row23_col1, #T_a9eca_row24_col1, #T_a9eca_row25_col1, #T_a9eca_row26_col1, #T_a9eca_row27_col1, #T_a9eca_row28_col1, #T_a9eca_row29_col1, #T_a9eca_row30_col1, #T_a9eca_row31_col1, #T_a9eca_row32_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_a9eca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9eca_level0_col0" class="col_heading level0 col0" >频数 (count)</th>
#       <th id="T_a9eca_level0_col1" class="col_heading level0 col1" >占比 (share)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >中国:制造业PMI</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9eca_level0_row0" class="row_heading level0 row0" >nan</th>
#       <td id="T_a9eca_row0_col0" class="data row0 col0" >22413</td>
#       <td id="T_a9eca_row0_col1" class="data row0 col1" >99.65%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row1" class="row_heading level0 row1" >50.100000</th>
#       <td id="T_a9eca_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_a9eca_row1_col1" class="data row1 col1" >0.04%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row2" class="row_heading level0 row2" >49.500000</th>
#       <td id="T_a9eca_row2_col0" class="data row2 col0" >7</td>
#       <td id="T_a9eca_row2_col1" class="data row2 col1" >0.03%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row3" class="row_heading level0 row3" >50.200000</th>
#       <td id="T_a9eca_row3_col0" class="data row3 col0" >6</td>
#       <td id="T_a9eca_row3_col1" class="data row3 col1" >0.03%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row4" class="row_heading level0 row4" >49.400000</th>
#       <td id="T_a9eca_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_a9eca_row4_col1" class="data row4 col1" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row5" class="row_heading level0 row5" >49.200000</th>
#       <td id="T_a9eca_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_a9eca_row5_col1" class="data row5 col1" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row6" class="row_heading level0 row6" >49.000000</th>
#       <td id="T_a9eca_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_a9eca_row6_col1" class="data row6 col1" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row7" class="row_heading level0 row7" >49.300000</th>
#       <td id="T_a9eca_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_a9eca_row7_col1" class="data row7 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row8" class="row_heading level0 row8" >49.700000</th>
#       <td id="T_a9eca_row8_col0" class="data row8 col0" >3</td>
#       <td id="T_a9eca_row8_col1" class="data row8 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row9" class="row_heading level0 row9" >49.100000</th>
#       <td id="T_a9eca_row9_col0" class="data row9 col0" >3</td>
#       <td id="T_a9eca_row9_col1" class="data row9 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row10" class="row_heading level0 row10" >51.900000</th>
#       <td id="T_a9eca_row10_col0" class="data row10 col0" >3</td>
#       <td id="T_a9eca_row10_col1" class="data row10 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row11" class="row_heading level0 row11" >50.900000</th>
#       <td id="T_a9eca_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_a9eca_row11_col1" class="data row11 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row12" class="row_heading level0 row12" >50.600000</th>
#       <td id="T_a9eca_row12_col0" class="data row12 col0" >2</td>
#       <td id="T_a9eca_row12_col1" class="data row12 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row13" class="row_heading level0 row13" >50.800000</th>
#       <td id="T_a9eca_row13_col0" class="data row13 col0" >2</td>
#       <td id="T_a9eca_row13_col1" class="data row13 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row14" class="row_heading level0 row14" >51.100000</th>
#       <td id="T_a9eca_row14_col0" class="data row14 col0" >2</td>
#       <td id="T_a9eca_row14_col1" class="data row14 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row15" class="row_heading level0 row15" >50.500000</th>
#       <td id="T_a9eca_row15_col0" class="data row15 col0" >2</td>
#       <td id="T_a9eca_row15_col1" class="data row15 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_a9eca_level0_row16" class="row_heading level0 row16" >49.800000</th>
#       <td id="T_a9eca_row16_col0" class="data row16 col0" >2</td>
# ...
# }
# #T_ff23a_row1_col1, #T_ff23a_row2_col1, #T_ff23a_row3_col1, #T_ff23a_row4_col1, #T_ff23a_row5_col1, #T_ff23a_row6_col1, #T_ff23a_row7_col1, #T_ff23a_row8_col1, #T_ff23a_row9_col1, #T_ff23a_row10_col1, #T_ff23a_row11_col1, #T_ff23a_row12_col1, #T_ff23a_row13_col1, #T_ff23a_row14_col1, #T_ff23a_row15_col1, #T_ff23a_row16_col1, #T_ff23a_row17_col1, #T_ff23a_row18_col1, #T_ff23a_row19_col1, #T_ff23a_row20_col1, #T_ff23a_row21_col1, #T_ff23a_row22_col1, #T_ff23a_row23_col1, #T_ff23a_row24_col1, #T_ff23a_row25_col1, #T_ff23a_row26_col1, #T_ff23a_row27_col1, #T_ff23a_row28_col1, #T_ff23a_row29_col1, #T_ff23a_row30_col1, #T_ff23a_row31_col1, #T_ff23a_row32_col1, #T_ff23a_row33_col1, #T_ff23a_row34_col1, #T_ff23a_row35_col1, #T_ff23a_row36_col1, #T_ff23a_row37_col1, #T_ff23a_row38_col1, #T_ff23a_row39_col1, #T_ff23a_row40_col1, #T_ff23a_row41_col1, #T_ff23a_row42_col1, #T_ff23a_row43_col1, #T_ff23a_row44_col1, #T_ff23a_row45_col1, #T_ff23a_row46_col1, #T_ff23a_row47_col1, #T_ff23a_row48_col1, #T_ff23a_row49_col1, #T_ff23a_row50_col1, #T_ff23a_row51_col1, #T_ff23a_row52_col1, #T_ff23a_row53_col1, #T_ff23a_row54_col1, #T_ff23a_row55_col1, #T_ff23a_row56_col1, #T_ff23a_row57_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_ff23a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff23a_level0_col0" class="col_heading level0 col0" >频数 (count)</th>
#       <th id="T_ff23a_level0_col1" class="col_heading level0 col1" >占比 (share)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >中国:M1:同比</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff23a_level0_row0" class="row_heading level0 row0" >nan</th>
#       <td id="T_ff23a_row0_col0" class="data row0 col0" >22413</td>
#       <td id="T_ff23a_row0_col1" class="data row0 col1" >99.65%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row1" class="row_heading level0 row1" >4.600000</th>
#       <td id="T_ff23a_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_ff23a_row1_col1" class="data row1 col1" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row2" class="row_heading level0 row2" >5.800000</th>
#       <td id="T_ff23a_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ff23a_row2_col1" class="data row2 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row3" class="row_heading level0 row3" >2.300000</th>
#       <td id="T_ff23a_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_ff23a_row3_col1" class="data row3 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row4" class="row_heading level0 row4" >4.700000</th>
#       <td id="T_ff23a_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_ff23a_row4_col1" class="data row4 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row5" class="row_heading level0 row5" >3.400000</th>
#       <td id="T_ff23a_row5_col0" class="data row5 col0" >3</td>
#       <td id="T_ff23a_row5_col1" class="data row5 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row6" class="row_heading level0 row6" >3.500000</th>
#       <td id="T_ff23a_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_ff23a_row6_col1" class="data row6 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row7" class="row_heading level0 row7" >0.400000</th>
#       <td id="T_ff23a_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_ff23a_row7_col1" class="data row7 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row8" class="row_heading level0 row8" >4.400000</th>
#       <td id="T_ff23a_row8_col0" class="data row8 col0" >2</td>
#       <td id="T_ff23a_row8_col1" class="data row8 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row9" class="row_heading level0 row9" >3.100000</th>
#       <td id="T_ff23a_row9_col0" class="data row9 col0" >2</td>
#       <td id="T_ff23a_row9_col1" class="data row9 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row10" class="row_heading level0 row10" >3.700000</th>
#       <td id="T_ff23a_row10_col0" class="data row10 col0" >2</td>
#       <td id="T_ff23a_row10_col1" class="data row10 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row11" class="row_heading level0 row11" >1.300000</th>
#       <td id="T_ff23a_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_ff23a_row11_col1" class="data row11 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row12" class="row_heading level0 row12" >6.700000</th>
#       <td id="T_ff23a_row12_col0" class="data row12 col0" >2</td>
#       <td id="T_ff23a_row12_col1" class="data row12 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row13" class="row_heading level0 row13" >5.100000</th>
#       <td id="T_ff23a_row13_col0" class="data row13 col0" >2</td>
#       <td id="T_ff23a_row13_col1" class="data row13 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row14" class="row_heading level0 row14" >3.300000</th>
#       <td id="T_ff23a_row14_col0" class="data row14 col0" >2</td>
#       <td id="T_ff23a_row14_col1" class="data row14 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row15" class="row_heading level0 row15" >5.500000</th>
#       <td id="T_ff23a_row15_col0" class="data row15 col0" >2</td>
#       <td id="T_ff23a_row15_col1" class="data row15 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row16" class="row_heading level0 row16" >6.100000</th>
#       <td id="T_ff23a_row16_col0" class="data row16 col0" >2</td>
#       <td id="T_ff23a_row16_col1" class="data row16 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row17" class="row_heading level0 row17" >6.800000</th>
#       <td id="T_ff23a_row17_col0" class="data row17 col0" >1</td>
#       <td id="T_ff23a_row17_col1" class="data row17 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row18" class="row_heading level0 row18" >0.000000</th>
#       <td id="T_ff23a_row18_col0" class="data row18 col0" >1</td>
#       <td id="T_ff23a_row18_col1" class="data row18 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row19" class="row_heading level0 row19" >2.900000</th>
#       <td id="T_ff23a_row19_col0" class="data row19 col0" >1</td>
#       <td id="T_ff23a_row19_col1" class="data row19 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row20" class="row_heading level0 row20" >5.000000</th>
#       <td id="T_ff23a_row20_col0" class="data row20 col0" >1</td>
#       <td id="T_ff23a_row20_col1" class="data row20 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row21" class="row_heading level0 row21" >4.800000</th>
#       <td id="T_ff23a_row21_col0" class="data row21 col0" >1</td>
#       <td id="T_ff23a_row21_col1" class="data row21 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row22" class="row_heading level0 row22" >6.500000</th>
#       <td id="T_ff23a_row22_col0" class="data row22 col0" >1</td>
#       <td id="T_ff23a_row22_col1" class="data row22 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row23" class="row_heading level0 row23" >6.900000</th>
#       <td id="T_ff23a_row23_col0" class="data row23 col0" >1</td>
#       <td id="T_ff23a_row23_col1" class="data row23 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row24" class="row_heading level0 row24" >8.000000</th>
#       <td id="T_ff23a_row24_col0" class="data row24 col0" >1</td>
#       <td id="T_ff23a_row24_col1" class="data row24 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_ff23a_level0_row25" class="row_heading level0 row25" >2.000000</th>
#       <td id="T_ff23a_row25_col0" class="data row25 col0
# ------------------------------
# 特征: '中国:M2:同比'
# <style type="text/css">
# #T_011f3_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# #T_011f3_row1_col1, #T_011f3_row2_col1, #T_011f3_row3_col1, #T_011f3_row4_col1, #T_011f3_row5_col1, #T_011f3_row6_col1, #T_011f3_row7_col1, #T_011f3_row8_col1, #T_011f3_row9_col1, #T_011f3_row10_col1, #T_011f3_row11_col1, #T_011f3_row12_col1, #T_011f3_row13_col1, #T_011f3_row14_col1, #T_011f3_row15_col1, #T_011f3_row16_col1, #T_011f3_row17_col1, #T_011f3_row18_col1, #T_011f3_row19_col1, #T_011f3_row20_col1, #T_011f3_row21_col1, #T_011f3_row22_col1, #T_011f3_row23_col1, #T_011f3_row24_col1, #T_011f3_row25_col1, #T_011f3_row26_col1, #T_011f3_row27_col1, #T_011f3_row28_col1, #T_011f3_row29_col1, #T_011f3_row30_col1, #T_011f3_row31_col1, #T_011f3_row32_col1, #T_011f3_row33_col1, #T_011f3_row34_col1, #T_011f3_row35_col1, #T_011f3_row36_col1, #T_011f3_row37_col1, #T_011f3_row38_col1, #T_011f3_row39_col1, #T_011f3_row40_col1, #T_011f3_row41_col1, #T_011f3_row42_col1, #T_011f3_row43_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 50.0%, transparent 50.0%);
# }
# </style>
# <table id="T_011f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_011f3_level0_col0" class="col_heading level0 col0" >频数 (count)</th>
#       <th id="T_011f3_level0_col1" class="col_heading level0 col1" >占比 (share)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >中国:M2:同比</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_011f3_level0_row0" class="row_heading level0 row0" >nan</th>
#       <td id="T_011f3_row0_col0" class="data row0 col0" >22413</td>
#       <td id="T_011f3_row0_col1" class="data row0 col1" >99.65%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row1" class="row_heading level0 row1" >8.300000</th>
#       <td id="T_011f3_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_011f3_row1_col1" class="data row1 col1" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row2" class="row_heading level0 row2" >8.400000</th>
#       <td id="T_011f3_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_011f3_row2_col1" class="data row2 col1" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row3" class="row_heading level0 row3" >8.500000</th>
#       <td id="T_011f3_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_011f3_row3_col1" class="data row3 col1" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row4" class="row_heading level0 row4" >11.100000</th>
#       <td id="T_011f3_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_011f3_row4_col1" class="data row4 col1" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row5" class="row_heading level0 row5" >7.000000</th>
#       <td id="T_011f3_row5_col0" class="data row5 col0" >4</td>
#       <td id="T_011f3_row5_col1" class="data row5 col1" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row6" class="row_heading level0 row6" >8.700000</th>
#       <td id="T_011f3_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_011f3_row6_col1" class="data row6 col1" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row7" class="row_heading level0 row7" >10.700000</th>
#       <td id="T_011f3_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_011f3_row7_col1" class="data row7 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row8" class="row_heading level0 row8" >10.100000</th>
#       <td id="T_011f3_row8_col0" class="data row8 col0" >3</td>
#       <td id="T_011f3_row8_col1" class="data row8 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row9" class="row_heading level0 row9" >8.200000</th>
#       <td id="T_011f3_row9_col0" class="data row9 col0" >3</td>
#       <td id="T_011f3_row9_col1" class="data row9 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row10" class="row_heading level0 row10" >8.600000</th>
#       <td id="T_011f3_row10_col0" class="data row10 col0" >2</td>
#       <td id="T_011f3_row10_col1" class="data row10 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row11" class="row_heading level0 row11" >8.000000</th>
#       <td id="T_011f3_row11_col0" class="data row11 col0" >2</td>
#       <td id="T_011f3_row11_col1" class="data row11 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row12" class="row_heading level0 row12" >10.300000</th>
#       <td id="T_011f3_row12_col0" class="data row12 col0" >2</td>
#       <td id="T_011f3_row12_col1" class="data row12 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row13" class="row_heading level0 row13" >8.800000</th>
#       <td id="T_011f3_row13_col0" class="data row13 col0" >2</td>
#       <td id="T_011f3_row13_col1" class="data row13 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row14" class="row_heading level0 row14" >8.100000</th>
#       <td id="T_011f3_row14_col0" class="data row14 col0" >2</td>
#       <td id="T_011f3_row14_col1" class="data row14 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row15" class="row_heading level0 row15" >10.500000</th>
#       <td id="T_011f3_row15_col0" class="data row15 col0" >2</td>
#       <td id="T_011f3_row15_col1" class="data row15 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row16" class="row_heading level0 row16" >11.800000</th>
#       <td id="T_011f3_row16_col0" class="data row16 col0" >2</td>
#       <td id="T_011f3_row16_col1" class="data row16 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row17" class="row_heading level0 row17" >12.400000</th>
#       <td id="T_011f3_row17_col0" class="data row17 col0" >2</td>
#       <td id="T_011f3_row17_col1" class="data row17 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row18" class="row_heading level0 row18" >9.400000</th>
#       <td id="T_011f3_row18_col0" class="data row18 col0" >2</td>
#       <td id="T_011f3_row18_col1" class="data row18 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row19" class="row_heading level0 row19" >9.700000</th>
#       <td id="T_011f3_row19_col0" class="data row19 col0" >2</td>
#       <td id="T_011f3_row19_col1" class="data row19 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row20" class="row_heading level0 row20" >6.300000</th>
#       <td id="T_011f3_row20_col0" class="data row20 col0" >2</td>
#       <td id="T_011f3_row20_col1" class="data row20 col1" >0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row21" class="row_heading level0 row21" >10.400000</th>
#       <td id="T_011f3_row21_col0" class="data row21 col0" >1</td>
#       <td id="T_011f3_row21_col1" class="data row21 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row22" class="row_heading level0 row22" >11.400000</th>
#       <td id="T_011f3_row22_col0" class="data row22 col0" >1</td>
#       <td id="T_011f3_row22_col1" class="data row22 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row23" class="row_heading level0 row23" >12.000000</th>
#       <td id="T_011f3_row23_col0" class="data row23 col0" >1</td>
#       <td id="T_011f3_row23_col1" class="data row23 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row24" class="row_heading level0 row24" >9.200000</th>
#       <td id="T_011f3_row24_col0" class="data row24 col0" >1</td>
#       <td id="T_011f3_row24_col1" class="data row24 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row25" class="row_heading level0 row25" >9.800000</th>
#       <td id="T_011f3_row25_col0" class="data row25 col0" >1</td>
#       <td id="T_011f3_row25_col1" class="data row25 col1" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_011f3_level0_row26" class="row_heading level0 row26" >10.900000</th>
#       <td id="T_011f3_row26_col0" class="data row26 col0" >1</td>
#       <td id="T_011f3_row26_col1"
# ------------------------------

# %% [markdown]
# # 日期EDA

# %%
def eda_date_column(df, column_name=None):
    """
    column_name :
        要分析的日期列的名称。
        如果为None，函数会按以下顺序自动查找：
        1. 寻找名为 '日期' 的列。
        2. 使用第0列作为日期列。
    """
    
    # --- 1. 自动定位和预处理日期列 ---
    df_copy = df.copy()
    
    if column_name:
        if column_name not in df_copy.columns:
            print(f"错误：列 '{column_name}' 不存在于DataFrame中。")
            return
    else:
        if '日期' in df_copy.columns:
            column_name = '日期'
        else:
            column_name = df_copy.columns[0]
            print(f"提示：未指定列名，已自动选择第0列 '{column_name}' 进行分析。")

    try:
        # 转换为datetime对象，errors='coerce'会把无法转换的值设为NaT
        df_copy[column_name] = pd.to_datetime(df_copy[column_name], errors='coerce')
        # 移除转换后为空的行
        original_rows = len(df_copy)
        df_copy.dropna(subset=[column_name], inplace=True)
        if len(df_copy) < original_rows:
            print(f"提示：已移除 {original_rows - len(df_copy)} 个无法解析的日期行。")
    except Exception as e:
        print(f"错误：转换列 '{column_name}' 为日期时失败: {e}")
        return
        
    print(f"EDA for Date Column: '{column_name}'")
    print("-" * 30)
    min_date = df_copy[column_name].min().strftime('%Y-%m-%d')
    max_date = df_copy[column_name].max().strftime('%Y-%m-%d')
    print(f"时间范围: {min_date} to {max_date}")
    print(f"总记录数: {len(df_copy)}")
    
    # --- 2. 提取日期特征 ---
    s = df_copy[column_name]
    features = {
        '年份': s.dt.year,
        '月份': s.dt.month,
        '星期': s.dt.day_name(),
        '季度': s.dt.quarter,
        '周数': s.dt.isocalendar().week,
    }
    features_df = pd.DataFrame(features)
    
    # --- 3. 创建多维度可视化仪表盘 ---
    # 移除了 font='SimHei'
    sns.set_theme(style="whitegrid") 
    fig, axes = plt.subplots(2, 2, figsize=(18, 14))
    fig.suptitle(f"Date Dimension Analysis Dashboard", fontsize=20, y=0.95)
    
    # 图1: 按月统计的总体趋势
    monthly_counts = s.dt.to_period('M').value_counts().sort_index()
    monthly_counts.index = monthly_counts.index.to_timestamp()
    sns.lineplot(data=monthly_counts, ax=axes[0, 0], marker='o', label='Monthly Record Count')
    axes[0, 0].set_title('Overall Trend (Monthly Counts)')
    axes[0, 0].set_xlabel('Date')
    axes[0, 0].set_ylabel('Count')
    
    # 图2: 按年份分布
    sns.countplot(data=features_df, x='年份', hue='年份', legend=False, ax=axes[0, 1], palette='viridis')
    axes[0, 1].set_title('Yearly Distribution')
    axes[0, 1].set_xlabel('Year')
    axes[0, 1].set_ylabel('Count')
    
    # 图3: 按月份分布 (年度周期性)
    month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
                   'July', 'August', 'September', 'October', 'November', 'December']
    
    month_counts = features_df['月份'].value_counts().sort_index()
    month_counts.index = month_counts.index.map(lambda x: pd.to_datetime(f'2000-{x}-01').strftime('%B'))
    month_counts = month_counts.reindex(month_order).fillna(0)

    sns.barplot(x=month_counts.index, hue=month_counts.index, legend=False, y=month_counts.values, ax=axes[1, 0], palette='coolwarm')
    axes[1, 0].set_title('Monthly Distribution (Annual Seasonality)')
    axes[1, 0].set_xlabel('Month')
    axes[1, 0].set_ylabel('Total Count')
    
    # 图4: 按星期分布 (周度周期性)
    day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    
    day_counts = features_df['星期'].value_counts().reindex(day_order)
    
    sns.barplot(x=day_counts.index, hue=day_counts.index, legend=False, y=day_counts.values, ax=axes[1, 1], palette='plasma')
    axes[1, 1].set_title('Weekly Distribution (Weekly Seasonality)')
    axes[1, 1].set_xlabel('Day of Week')
    axes[1, 1].set_ylabel('Total Count')
    
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

    # --- 4. [优雅的可视化] 绘制日历热力图, 黄色说明有活动,灰色说明没这个日期 ---
    try:
        print("\n" + "-" * 30)
        print("Annual Activity Calendar Heatmap")
        daily_counts = s.dt.date.value_counts()
        daily_counts.index = pd.to_datetime(daily_counts.index)
        
        # 为每个年份绘制一张图
        for year in sorted(daily_counts.index.year.unique()):
            plt.figure(figsize=(18, 3))
            calmap.yearplot(daily_counts, year=year, cmap='YlGn')
            plt.suptitle(f'{year} Calendar Heatmap', fontsize=16, y=1.02)
            plt.show()
    except Exception as e:
        print(f"提示：无法绘制日历热力图，可能因为数据量或日期范围问题。错误: {e}")

eda_date_column(df)
# Out:
# 提示：未指定列名，已自动选择第0列 '指标名称' 进行分析。
# 提示：已移除 22413 个无法解析的日期行。
# EDA for Date Column: '指标名称'
# ------------------------------
# 时间范围: 2019-01-01 to 2025-07-01
# 总记录数: 79
# /tmp/ipykernel_3972222/2474943681.py:26: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_copy[column_name] = pd.to_datetime(df_copy[column_name], errors='coerce')
# ------------------------------
# Annual Activity Calendar Heatmap

# %% [markdown]
# # 相关性分析

# %%
def encode_FE(df, cols):
    for col in cols:
        vc = df[col].value_counts(dropna=True, normalize=True).to_dict()
        df[col] = df[col].map(vc)
        df[col] = df[col].astype('float32')
    return df

def analyze_correlation(df):
    """
    自动预处理DataFrame并分析列之间的相关性。

    过程:
    1. 复制原始DataFrame以避免修改。
    2. 自动检测并转换日期/时间类型的列 (包括字符串格式) 为Unix时间戳。
    3. 对剩余的字符串(分类)列进行频率编码。
    4. 计算处理后所有数值列的相关性矩阵。

    参数:
        df (pd.DataFrame): 需要分析的输入DataFrame。

    返回:
        tuple: 一个包含两个元素的元组:
            - (pd.DataFrame): 经过预处理的全数值DataFrame。
            - (pd.DataFrame): 计算出的相关性矩阵。
    """
    print("--- 启动分析流程 ---")
    df_processed = df.copy()

    # 步骤 1: 优先处理日期/时间类型的列
    # 这样可以避免日期字符串被错误地当作普通分类变量处理
    date_cols_found = []
    for col in df_processed.columns:
        # 只尝试转换非数值类型的列
        if df_processed[col].dtype == 'object' or pd.api.types.is_datetime64_any_dtype(df_processed[col].dtype):
            try:
                # 尝试将列转换为datetime格式，无法转换的值会变为NaT
                temp_dt = pd.to_datetime(df_processed[col], errors='coerce')
                
                # 如果转换后至少有一个有效日期，则认为该列是日期列
                if not temp_dt.isnull().all():
                    print(f"检测到日期/时间列: '{col}' -> 转换为Unix时间戳")
                    # 转换为以秒为单位的Unix时间戳
                    df_processed[col] = temp_dt.astype('int64') // 10**9
                    date_cols_found.append(col)
            except (ValueError, TypeError):
                # 如果转换失败，说明不是日期列，跳过
                continue
    
    # 步骤 2: 处理剩余的字符串 (分类) 列
    # 选择所有数据类型仍为 'object' 的列
    str_cols_to_encode = df_processed.select_dtypes(include=['object']).columns.tolist()

    if str_cols_to_encode:
        print(f"检测到字符/分类列: {str_cols_to_encode} -> 进行频率编码")
        df_processed = encode_FE(df_processed, str_cols_to_encode)
    else:
        print("未找到需要频率编码的字符/分类列。")

    # 步骤 3: 计算相关性矩阵
    # 确保所有列都是数值类型
    numeric_cols = df_processed.select_dtypes(include=np.number).columns.tolist()
    if len(numeric_cols) != len(df_processed.columns):
        print("\n警告: 并非所有列都能转换为数值类型。相关性将只在数值列上计算。")
    
    print("正在计算相关性矩阵...")
    correlation_matrix = df_processed[numeric_cols].corr()
    
    print("--- 分析流程结束 ---")
    return df_processed, correlation_matrix

df_processed_result, correlation_matrix_result = analyze_correlation(df)
print(correlation_matrix_result)

print("\n\n" + "="*50)
print("      各列的 Top 5 最高相关性分析")
print("="*50)

# 遍历相关性矩阵中的每一列
for column in correlation_matrix_result.columns:
    print(f"\n--- 与 '{column}' 相关性最高的 Top 5 列 ---")
    correlations = correlation_matrix_result[column].drop(column)
    
    # 2. 找到绝对值最高的5个相关性的索引 (列名)
    #    使用 .abs() 来确保强负相关也被认为是“高”相关性
    #    使用 .nlargest(5) 来高效获取前5个值
    top_5_indices = correlations.abs().nlargest(5).index
    
    # 3. 使用这些索引从原始的相关性级数中 (包含正负号) 获取并显示结果
    top_5_values = correlations.loc[top_5_indices]
    
    # 4. 检查是否有足够的相关列可供显示
    if top_5_values.empty:
        print("没有其他列可进行相关性比较。")
    else:
        print(top_5_values)
# Out:
# --- 启动分析流程 ---
# 检测到日期/时间列: '指标名称' -> 转换为Unix时间戳
# 检测到字符/分类列: ['中国:社会融资规模:当月值'] -> 进行频率编码
# 正在计算相关性矩阵...
# --- 分析流程结束 ---
#                               指标名称  美国:CPI:同比  美国:PPI:最终需求:同比:季调  \
# 指标名称                      1.000000   0.231537           0.102316
# 美国:CPI:同比                 0.231537   1.000000           0.919879
# 美国:PPI:最终需求:同比:季调         0.102316   0.919879           1.000000
# 欧元区:HICP(调和CPI):当月同比      0.317179   0.878469           0.675553
# 欧元区20国:PPI:当月同比          -0.053372   0.886922           0.915888
# 中国:制造业PMI                -0.036425  -0.101271          -0.048758
# 中国:工业企业:利润总额:当月同比        -0.176871  -0.035982           0.088280
# 中国:CPI:当月同比              -0.687684   0.014664           0.040088
# 中国:PPI:全部工业品:当月同比        -0.265284   0.610829           0.816774
# 中国:房地产开发投资完成额:累计同比       -0.684032  -0.149992           0.079949
# 美国:拖欠率:信用卡消费贷款:所有商业银行:季调  0.036401  -0.060502          -0.090985
# 美国:拖欠率:房地产贷款:所有商业银行:季调   -0.065915  -0.040490          -0.022476
# 中国:零售渗透率:新能源乘用车           0.162414   0.041175           0.017295
# 中国:社会融资规模:当月值                  NaN        NaN                NaN
# 中国:M1:同比                 -0.446393   0.031905           0.040912
# 中国:M2:同比                 -0.156046   0.373989           0.139385
#
#                           欧元区:HICP(调和CPI):当月同比  欧元区20国:PPI:当月同比  中国:制造业PMI  \
# 指标名称                                  0.317179        -0.053372  -0.036425
# 美国:CPI:同比                             0.878469         0.886922  -0.101271
# 美国:PPI:最终需求:同比:季调                     0.675553         0.915888  -0.048758
# 欧元区:HICP(调和CPI):当月同比                  1.000000         0.745778  -0.144628
# 欧元区20国:PPI:当月同比                       0.745778         1.000000  -0.064625
# 中国:制造业PMI                            -0.144628        -0.064625   1.000000
# 中国:工业企业:利润总额:当月同比                    -0.215023        -0.010244   0.189336
# 中国:CPI:当月同比                          -0.017157         0.229266  -0.251611
# 中国:PPI:全部工业品:当月同比                     0.226619         0.673659   0.030143
# 中国:房地产开发投资完成额:累计同比                   -0.359841         0.050478   0.324156
# 美国:拖欠率:信用卡消费贷款:所有商业银行:季调             -0.031137        -0.093130   0.143115
# 美国:拖欠率:房地产贷款:所有商业银行:季调               -0.069085        -0.025391   0.187486
# 中国:零售渗透率:新能源乘用车                       0.061948        -0.011124  -0.065271
# 中国:社会融资规模:当月值                              NaN              NaN        NaN
# 中国:M1:同比                              0.023307         0.212288   0.191584
# 中国:M2:同比                              0.574586         0.375741   0.072776
#
#                           中国:工业企业:利润总额:当月同比  中国:CPI:当月同比  中国:PPI:全部工业品:当月同比  \
# 指标名称                              -0.176871    -0.687684          -0.265284
# 美国:CPI:同比                         -0.035982     0.014664           0.610829
# 美国:PPI:最终需求:同比:季调                  0.088280     0.040088           0.816774
# 欧元区:HICP(调和CPI):当月同比              -0.215023    -0.017157           0.226619
# 欧元区20国:PPI:当月同比                   -0.010244     0.229266           0.673659
# 中国:制造业PMI                          0.189336    -0.251611           0.030143
# 中国:工业企业:利润总额:当月同比                  1.000000    -0.150926           0.324072
# 中国:CPI:当月同比                       -0.150926     1.000000           0.155170
# 中国:PPI:全部工业品:当月同比                  0.324072     0.155170           1.000000
# 中国:房地产开发投资完成额:累计同比                 0.479553     0.214165           0.465659
# 美国:拖欠率:信用卡消费贷款:所有商业银行:季调          -0.026602    -0.008320          -0.098071
# 美国:拖欠率:房地产贷款:所有商业银行:季调             0.092231     0.027932           0.024486
# 中国:零售渗透率:新能源乘用车                    0.074005    -0.109497          -0.054158
# 中国:社会融资规模:当月值                           NaN          NaN                NaN
# 中国:M1:同比                           0.290277     0.163888           0.124781
# 中国:M2:同比                          -0.036231     0.145112          -0.068063
#
#                           中国:房地产开发投资完成额:累计同比  美国:拖欠率:信用卡消费贷款:所有商业银行:季调  \
# 指标名称                               -0.684032                  0.036401
# 美国:CPI:同比                          -0.149992                 -0.060502
# 美国:PPI:最终需求:同比:季调                   0.079949                 -0.090985
# 欧元区:HICP(调和CPI):当月同比               -0.359841                 -0.031137
# 欧元区20国:PPI:当月同比                     0.050478                 -0.093130
# 中国:制造业PMI                           0.324156                  0.143115
# 中国:工业企业:利润总额:当月同比                   0.479553                 -0.026602
# 中国:CPI:当月同比                         0.214165                 -0.008320
# 中国:PPI:全部工业品:当月同比                   0.465659                 -0.098071
# 中国:房地产开发投资完成额:累计同比                  1.000000                 -0.069115
# 美国:拖欠率:信用卡消费贷款:所有商业银行:季调           -0.069115                  1.000000
# 美国:拖欠率:房地产贷款:所有商业银行:季调              0.066112                  0.949602
# 中国:零售渗透率:新能源乘用车                    -0.153181                  0.381290
# 中国:社会融资规模:当月值                            NaN                       NaN
# 中国:M1:同比                            0.391580                 -0.061675
# 中国:M2:同比                           -0.077322                 -0.022574
#
#                           美国:拖欠率:房地产贷款:所有商业银行:季调  中国:零售渗透率:新能源乘用车  \
# 指标名称                                   -0.065915         0.162414
# 美国:CPI:同比                              -0.040490         0.041175
# 美国:PPI:最终需求:同比:季调                      -0.022476         0.017295
# 欧元区:HICP(调和CPI):当月同比                   -0.069085         0.061948
# 欧元区20国:PPI:当月同比                        -0.025391        -0.011124
# 中国:制造业PMI                               0.187486        -0.065271
# 中国:工业企业:利润总额:当月同比                       0.092231         0.074005
# 中国:CPI:当月同比                             0.027932        -0.109497
# 中国:PPI:全部工业品:当月同比                       0.024486        -0.054158
# 中国:房地产开发投资完成额:累计同比                      0.066112        -0.153181
# 美国:拖欠率:信用卡消费贷款:所有商业银行:季调                0.949602         0.381290
# 美国:拖欠率:房地产贷款:所有商业银行:季调                  1.000000         0.317310
# 中国:零售渗透率:新能源乘用车                         0.317310         1.000000
# 中国:社会融资规模:当月值                                NaN              NaN
# 中国:M1:同比                                0.047025        -0.100881
# 中国:M2:同比                               -0.004452        -0.023306
#
#                           中国:社会融资规模:当月值  中国:M1:同比  中国:M2:同比
# 指标名称                                NaN -0.446393 -0.156046
# 美国:CPI:同比                           NaN  0.031905  0.373989
# 美国:PPI:最终需求:同比:季调                   NaN  0.040912  0.139385
# 欧元区:HICP(调和CPI):当月同比                NaN  0.023307  0.574586
# 欧元区20国:PPI:当月同比                     NaN  0.212288  0.375741
# 中国:制造业PMI                           NaN  0.191584  0.072776
# 中国:工业企业:利润总额:当月同比                   NaN  0.290277 -0.036231
# 中国:CPI:当月同比                         NaN  0.163888  0.145112
# 中国:PPI:全部工业品:当月同比                   NaN  0.124781 -0.068063
# 中国:房地产开发投资完成额:累计同比                  NaN  0.391580 -0.077322
# 美国:拖欠率:信用卡消费贷款:所有商业银行:季调            NaN -0.061675 -0.022574
# 美国:拖欠率:房地产贷款:所有商业银行:季调              NaN  0.047025 -0.004452
# 中国:零售渗透率:新能源乘用车                     NaN -0.100881 -0.023306
# 中国:社会融资规模:当月值                       NaN       NaN       NaN
# 中国:M1:同比                            NaN  1.000000  0.596536
# 中国:M2:同比                            NaN  0.596536  1.000000
#
#
# ==================================================
#       各列的 Top 5 最高相关性分析
# ==================================================
#
# --- 与 '指标名称' 相关性最高的 Top 5 列 ---
# 中国:CPI:当月同比            -0.687684
# 中国:房地产开发投资完成额:累计同比     -0.684032
# 中国:M1:同比               -0.446393
# 欧元区:HICP(调和CPI):当月同比    0.317179
# 中国:PPI:全部工业品:当月同比      -0.265284
# Name: 指标名称, dtype: float64
#
# --- 与 '美国:CPI:同比' 相关性最高的 Top 5 列 ---
# 美国:PPI:最终需求:同比:季调       0.919879
# 欧元区20国:PPI:当月同比         0.886922
# 欧元区:HICP(调和CPI):当月同比    0.878469
# 中国:PPI:全部工业品:当月同比       0.610829
# 中国:M2:同比                0.373989
# Name: 美国:CPI:同比, dtype: float64
#
# --- 与 '美国:PPI:最终需求:同比:季调' 相关性最高的 Top 5 列 ---
# 美国:CPI:同比               0.919879
# 欧元区20国:PPI:当月同比         0.915888
# 中国:PPI:全部工业品:当月同比       0.816774
# 欧元区:HICP(调和CPI):当月同比    0.675553
# 中国:M2:同比                0.139385
# Name: 美国:PPI:最终需求:同比:季调, dtype: float64
#
# --- 与 '欧元区:HICP(调和CPI):当月同比' 相关性最高的 Top 5 列 ---
# 美国:CPI:同比             0.878469
# 欧元区20国:PPI:当月同比       0.745778
# 美国:PPI:最终需求:同比:季调     0.675553
# 中国:M2:同比              0.574586
# 中国:房地产开发投资完成额:累计同比   -0.359841
# Name: 欧元区:HICP(调和CPI):当月同比, dtype: float64
#
# --- 与 '欧元区20国:PPI:当月同比' 相关性最高的 Top 5 列 ---
# 美国:PPI:最终需求:同比:季调       0.915888
# 美国:CPI:同比               0.886922
# 欧元区:HICP(调和CPI):当月同比    0.745778
# 中国:PPI:全部工业品:当月同比       0.673659
# 中国:M2:同比                0.375741
# Name: 欧元区20国:PPI:当月同比, dtype: float64
#
# --- 与 '中国:制造业PMI' 相关性最高的 Top 5 列 ---
# 中国:房地产开发投资完成额:累计同比        0.324156
# 中国:CPI:当月同比              -0.251611
# 中国:M1:同比                  0.191584
# 中国:工业企业:利润总额:当月同比         0.189336
# 美国:拖欠率:房地产贷款:所有商业银行:季调    0.187486
# Name: 中国:制造业PMI, dtype: float64
#
# --- 与 '中国:工业企业:利润总额:当月同比' 相关性最高的 Top 5 列 ---
# 中国:房地产开发投资完成额:累计同比      0.479553
# 中国:PPI:全部工业品:当月同比       0.324072
# 中国:M1:同比                0.290277
# 欧元区:HICP(调和CPI):当月同比   -0.215023
# 中国:制造业PMI               0.189336
# Name: 中国:工业企业:利润总额:当月同比, dtype: float64
#
# --- 与 '中国:CPI:当月同比' 相关性最高的 Top 5 列 ---
# 指标名称                 -0.687684
# 中国:制造业PMI            -0.251611
# 欧元区20国:PPI:当月同比       0.229266
# 中国:房地产开发投资完成额:累计同比    0.214165
# 中国:M1:同比              0.163888
# Name: 中国:CPI:当月同比, dtype: float64
#
# --- 与 '中国:PPI:全部工业品:当月同比' 相关性最高的 Top 5 列 ---
# 美国:PPI:最终需求:同比:季调     0.816774
# 欧元区20国:PPI:当月同比       0.673659
# 美国:CPI:同比             0.610829
# 中国:房地产开发投资完成额:累计同比    0.465659
# 中国:工业企业:利润总额:当月同比     0.324072
# Name: 中国:PPI:全部工业品:当月同比, dtype: float64
#
# --- 与 '中国:房地产开发投资完成额:累计同比' 相关性最高的 Top 5 列 ---
# 指标名称                   -0.684032
# 中国:工业企业:利润总额:当月同比       0.479553
# 中国:PPI:全部工业品:当月同比       0.465659
# 中国:M1:同比                0.391580
# 欧元区:HICP(调和CPI):当月同比   -0.359841
# Name: 中国:房地产开发投资完成额:累计同比, dtype: float64
#
# --- 与 '美国:拖欠率:信用卡消费贷款:所有商业银行:季调' 相关性最高的 Top 5 列 ---
# 美国:拖欠率:房地产贷款:所有商业银行:季调    0.949602
# 中国:零售渗透率:新能源乘用车           0.381290
# 中国:制造业PMI                 0.143115
# 中国:PPI:全部工业品:当月同比        -0.098071
# 欧元区20国:PPI:当月同比          -0.093130
# Name: 美国:拖欠率:信用卡消费贷款:所有商业银行:季调, dtype: float64
#
# --- 与 '美国:拖欠率:房地产贷款:所有商业银行:季调' 相关性最高的 Top 5 列 ---
# 美国:拖欠率:信用卡消费贷款:所有商业银行:季调    0.949602
# 中国:零售渗透率:新能源乘用车             0.317310
# 中国:制造业PMI                   0.187486
# 中国:工业企业:利润总额:当月同比           0.092231
# 欧元区:HICP(调和CPI):当月同比       -0.069085
# Name: 美国:拖欠率:房地产贷款:所有商业银行:季调, dtype: float64
#
# --- 与 '中国:零售渗透率:新能源乘用车' 相关性最高的 Top 5 列 ---
# 美国:拖欠率:信用卡消费贷款:所有商业银行:季调    0.381290
# 美国:拖欠率:房地产贷款:所有商业银行:季调      0.317310
# 指标名称                        0.162414
# 中国:房地产开发投资完成额:累计同比         -0.153181
# 中国:CPI:当月同比                -0.109497
# Name: 中国:零售渗透率:新能源乘用车, dtype: float64
#
# --- 与 '中国:社会融资规模:当月值' 相关性最高的 Top 5 列 ---
# 指标名称                   NaN
# 美国:CPI:同比              NaN
# 美国:PPI:最终需求:同比:季调      NaN
# 欧元区:HICP(调和CPI):当月同比   NaN
# 欧元区20国:PPI:当月同比        NaN
# Name: 中国:社会融资规模:当月值, dtype: float64
#
# --- 与 '中国:M1:同比' 相关性最高的 Top 5 列 ---
# 中国:M2:同比              0.596536
# 指标名称                 -0.446393
# 中国:房地产开发投资完成额:累计同比    0.391580
# 中国:工业企业:利润总额:当月同比     0.290277
# 欧元区20国:PPI:当月同比       0.212288
# Name: 中国:M1:同比, dtype: float64
#
# --- 与 '中国:M2:同比' 相关性最高的 Top 5 列 ---
# 中国:M1:同比                0.596536
# 欧元区:HICP(调和CPI):当月同比    0.574586
# 欧元区20国:PPI:当月同比         0.375741
# 美国:CPI:同比               0.373989
# 指标名称                   -0.156046
# Name: 中国:M2:同比, dtype: float64
# /tmp/ipykernel_3972222/326313969.py:37: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   temp_dt = pd.to_datetime(df_processed[col], errors='coerce')
# /tmp/ipykernel_3972222/326313969.py:37: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   temp_dt = pd.to_datetime(df_processed[col], errors='coerce')
